# %% [markdown]
# # Notebook 02d — Feature Engineering v2 (Early time-series features)
#
# ## Goal
# Create a stronger clone-level feature table using early passages only (default: 3–10),
# with features that better capture early dynamics for predicting late outcomes.
#
# Compared to v1, we add:
# - last-value features (passage 10)
# - split-window slopes (3–6 vs 7–10)
# - curvature (slope change)
# - qP proxies (titer / VCD)
# - CV (std / mean)
#
# Outputs:
# - `data/synthetic/processed/cld_features_v2.csv`
# - `data/synthetic/processed/cld_features_with_label_v2.csv`

# %%
import sqlite3
import pandas as pd
import numpy as np
from pathlib import Path

scenario = "optimized" # 'legacy' or 'optimized'
n_clones = 5000

DB_PATH = f"../data/synthetic/raw/cld_{n_clones}clones_{scenario}.db"
OUT_DIR = Path("../data/synthetic/processed")
OUT_FEATURES = OUT_DIR / f"cld_features_v2_{n_clones}_{scenario}.csv"
OUT_LABELS = OUT_DIR / f"cld_features_with_label_v2_{n_clones}_{scenario}.csv"

conn = sqlite3.connect(DB_PATH)

print("Connected to:", DB_PATH)
print("Will save features to:", OUT_FEATURES)
print("Will save labels to:", OUT_LABELS)
# Out:
# Connected to: ../data/synthetic/raw/cld_5000clones_legacy.db

# %%
assay = pd.read_sql_query("""
SELECT 
  ar.assay_id,
  ar.assay_type,
  ar.value,
  ar.unit,
  ar.method,
  ar.batch_id,
  p.clone_id,
  p.passage_number,
  p.phase
FROM assay_result ar
JOIN passage p
  ON p.passage_id = ar.passage_id
""", conn)

assay.head()
# Out:
#                            assay_id   assay_type         value      unit  \
# 0        ASSAY_CLONE_0001_P01_titer        titer  3.639742e+00       g/L
# 1          ASSAY_CLONE_0001_P01_vcd          vcd  1.054184e+07  cells/mL
# 2    ASSAY_CLONE_0001_P01_viability    viability  9.096341e+01         %
# 3  ASSAY_CLONE_0001_P01_aggregation  aggregation  5.877167e+00         %
# 4        ASSAY_CLONE_0001_P02_titer        titer  3.494621e+00       g/L
#
#      method batch_id    clone_id  passage_number  phase
# 0     ELISA    B_P01  CLONE_0001               1  early
# 1   Vi-CELL    B_P01  CLONE_0001               1  early
# 2   Vi-CELL    B_P01  CLONE_0001               1  early
# 3  SEC-HPLC    B_P01  CLONE_0001               1  early
# 4     ELISA    B_P02  CLONE_0001               2  early

# %% [markdown]
# We exclude passage 1–2 due to frequent outlier behavior in real CLD.

# %%
EARLY_START = 3
EARLY_END = 10

assay_early = assay[(assay["passage_number"] >= EARLY_START) & (assay["passage_number"] <= EARLY_END)].copy()
print("Assay early rows:", len(assay_early))
assay_early.head()
# Out:
# Assay early rows: 165000
#                             assay_id   assay_type         value         unit  \
# 8         ASSAY_CLONE_0001_P03_titer        titer  3.345283e+00          g/L
# 9           ASSAY_CLONE_0001_P03_vcd          vcd  1.066725e+07     cells/mL
# 10    ASSAY_CLONE_0001_P03_viability    viability  9.393675e+01            %
# 11  ASSAY_CLONE_0001_P03_aggregation  aggregation  5.840737e+00            %
# 12     ASSAY_CLONE_0001_P03_ddpcr_cn     ddpcr_cn  4.000000e+00  copies/cell
#
#       method batch_id    clone_id  passage_number  phase
# 8      ELISA    B_P03  CLONE_0001               3  early
# 9    Vi-CELL    B_P03  CLONE_0001               3  early
# 10   Vi-CELL    B_P03  CLONE_0001               3  early
# 11  SEC-HPLC    B_P03  CLONE_0001               3  early
# 12     ddPCR    B_P03  CLONE_0001               3  early

# %%
# -----------------------------
# ddPCR copy number feature (clone-level)
# - ddpcr_cn is stored once per clone at passage = EARLY_START (e.g., 3)
# - We convert it to a single clone-level feature column: ddpcr_cn
# -----------------------------

ddpcr = assay_early[assay_early["assay_type"] == "ddpcr_cn"][["clone_id", "value"]].copy()
ddpcr = ddpcr.rename(columns={"value": "ddpcr_cn"})

# If multiple rows exist (shouldn't, but safe), take mean
ddpcr = ddpcr.groupby("clone_id", as_index=False)["ddpcr_cn"].mean()

print("ddPCR rows:", len(ddpcr))
ddpcr.head()
# Out:
# ddPCR rows: 5000
#      clone_id  ddpcr_cn
# 0  CLONE_0001       4.0
# 1  CLONE_0002       2.0
# 2  CLONE_0003       5.0
# 3  CLONE_0004       4.0
# 4  CLONE_0005       6.0

# %%
early_wide = assay_early.pivot_table(
    index=["clone_id", "passage_number"],
    columns="assay_type",
    values="value",
    aggfunc="mean"
).reset_index()

early_wide.head()
# Out:
# assay_type    clone_id  passage_number  aggregation  ddpcr_cn     titer  \
# 0           CLONE_0001               3     5.840737       4.0  3.345283
# 1           CLONE_0001               4     6.131483       NaN  3.439919
# 2           CLONE_0001               5     5.864629       NaN  3.115586
# 3           CLONE_0001               6     5.762380       NaN  3.188244
# 4           CLONE_0001               7     6.118738       NaN  3.057736
#
# assay_type           vcd  viability
# 0           1.066725e+07  93.936746
# 1           1.061611e+07  92.602956
# 2           1.121001e+07  91.868214
# 3           1.093385e+07  96.268296
# 4           1.092804e+07  94.993793

# %%
metrics = ["titer", "vcd", "viability", "aggregation"]

agg_dict = {m: ["mean", "std", "min", "max"] for m in metrics}

summary = early_wide.groupby("clone_id")[metrics].agg(agg_dict)
summary.columns = [f"{c[0]}_{c[1]}" for c in summary.columns]
summary = summary.reset_index()

summary.head()
# Out:
#      clone_id  titer_mean  titer_std  titer_min  titer_max      vcd_mean  \
# 0  CLONE_0001    3.142136   0.219271   2.698838   3.439919  1.083374e+07
# 1  CLONE_0002    0.904944   0.109603   0.803284   1.141559  1.480237e+07
# 2  CLONE_0003    5.045860   0.382916   4.372261   5.533843  8.915354e+06
# 3  CLONE_0004    1.354368   0.364467   0.587097   1.712960  1.422009e+07
# 4  CLONE_0005    3.365629   0.253995   3.046187   3.803560  1.080455e+07
#
#         vcd_std       vcd_min       vcd_max  viability_mean  viability_std  \
# 0  5.675920e+05  1.013179e+07  1.192629e+07       94.797460       1.812446
# 1  1.073024e+06  1.360551e+07  1.648285e+07       95.662931       1.214252
# 2  6.404794e+05  7.768218e+06  9.791953e+06       93.506606       2.367175
# 3  1.112143e+06  1.266285e+07  1.564230e+07       95.995496       1.301568
# 4  1.224111e+06  9.122992e+06  1.251044e+07       94.013308       1.623971
#
#    viability_min  viability_max  aggregation_mean  aggregation_std  \
# 0      91.868214      96.744697          5.975000         0.158172
# 1      94.044085      97.284314          6.688873         0.324162
# 2      89.381706      97.082336          2.602620         0.286036
# 3      94.007382      97.551388          1.688844         0.644064
# 4      91.641345      95.835932          2.859277         0.189038
#
#    aggregation_min  aggregation_max
# 0         5.762380         6.201742
# 1         6.136902         7.160212
# 2         2.225879         3.109780
# 3         0.668980         2.359712
# 4         2.558331         3.094070

# %%
def slope(x, y):
    if len(x) < 2:
        return np.nan
    return np.polyfit(x, y, 1)[0]

slope_rows = []
for clone_id, df in early_wide.groupby("clone_id"):
    x = df["passage_number"].values
    row = {"clone_id": clone_id}
    for m in metrics:
        row[f"{m}_slope"] = slope(x, df[m].values) if m in df.columns else np.nan
    slope_rows.append(row)

slopes = pd.DataFrame(slope_rows)
slopes.head()
# Out:
#      clone_id  titer_slope      vcd_slope  viability_slope  aggregation_slope
# 0  CLONE_0001    -0.071671    5186.257702         0.562964           0.020311
# 1  CLONE_0002     0.023970  307661.485112         0.285633           0.060379
# 2  CLONE_0003    -0.139841  -54354.705173         0.641537           0.051292
# 3  CLONE_0004    -0.113480  173771.245831        -0.181241           0.001420
# 4  CLONE_0005    -0.068334   -8059.222769         0.016623          -0.011101

# %%
# last value at EARLY_END (e.g., p10)
last_df = early_wide[early_wide["passage_number"] == EARLY_END][["clone_id"] + metrics].copy()
last_df = last_df.rename(columns={m: f"{m}_p{EARLY_END}" for m in metrics})

last_df.head()
# Out:
# assay_type    clone_id  titer_p10       vcd_p10  viability_p10  \
# 7           CLONE_0001   2.698838  1.025656e+07      96.744697
# 15          CLONE_0002   1.141559  1.527193e+07      96.525476
# 23          CLONE_0003   4.788162  7.768218e+06      97.082336
# 31          CLONE_0004   0.587097  1.564230e+07      94.778537
# 39          CLONE_0005   3.063033  1.061955e+07      92.543213
#
# assay_type  aggregation_p10
# 7                  5.959162
# 15                 7.160212
# 23                 3.109780
# 31                 2.133877
# 39                 3.094070

# %%
def slope_in_window(df, m, start_p, end_p):
    d = df[(df["passage_number"] >= start_p) & (df["passage_number"] <= end_p)]
    if len(d) < 2 or m not in d.columns:
        return np.nan
    return slope(d["passage_number"].values, d[m].values)

split_rows = []
for clone_id, df in early_wide.groupby("clone_id"):
    row = {"clone_id": clone_id}
    for m in metrics:
        row[f"{m}_slope_{EARLY_START}_6"] = slope_in_window(df, m, EARLY_START, 6)
        row[f"{m}_slope_7_{EARLY_END}"] = slope_in_window(df, m, 7, EARLY_END)
        # curvature = change in slope (late - early)
        row[f"{m}_curvature"] = row[f"{m}_slope_7_{EARLY_END}"] - row[f"{m}_slope_{EARLY_START}_6"]
    split_rows.append(row)

splits = pd.DataFrame(split_rows)
splits.head()
# Out:
#      clone_id  titer_slope_3_6  titer_slope_7_10  titer_curvature  \
# 0  CLONE_0001        -0.079545         -0.106105        -0.026560
# 1  CLONE_0002        -0.039500          0.092261         0.131760
# 2  CLONE_0003        -0.186770         -0.131713         0.055057
# 3  CLONE_0004         0.035691         -0.160056        -0.195746
# 4  CLONE_0005         0.107886         -0.121743        -0.229629
#
#    vcd_slope_3_6  vcd_slope_7_10  vcd_curvature  viability_slope_3_6  \
# 0  139369.075231   -21993.968149  -1.613630e+05             0.625991
# 1   77493.097923  -323985.862050  -4.014790e+05            -0.191218
# 2  -49589.992020  -543480.292682  -4.938903e+05             0.903934
# 3  640199.110774   135306.963297  -5.048921e+05            -0.476540
# 4  403850.329104  -721727.801260  -1.125578e+06            -0.689474
#
#    viability_slope_7_10  viability_curvature  aggregation_slope_3_6  \
# 0              0.492006            -0.133985              -0.050192
# 1              0.728523             0.919741               0.195536
# 2              1.398430             0.494496               0.040310
# 3             -0.181175             0.295365              -0.092572
# 4             -1.060788            -0.371313              -0.058896
#
#    aggregation_slope_7_10  aggregation_curvature
# 0               -0.019811               0.030381
# 1                0.298181               0.102646
# 2                0.318995               0.278685
# 3               -0.124875              -0.032303
# 4                0.049325               0.108220

# %%
# qP proxy: titer / vcd
# add small epsilon to avoid division issues
eps = 1e-9

qp = summary[["clone_id"]].copy()
qp["qP_mean"] = summary["titer_mean"] / (summary["vcd_mean"] + eps)

# merge last values for p10
last_for_qp = last_df[["clone_id", f"titer_p{EARLY_END}", f"vcd_p{EARLY_END}"]].copy()
qp = qp.merge(last_for_qp, on="clone_id", how="left")

qp["qP_p10"] = qp[f"titer_p{EARLY_END}"] / (qp[f"vcd_p{EARLY_END}"] + eps)

# optional: drop the temporary columns
qp = qp.drop(columns=[f"titer_p{EARLY_END}", f"vcd_p{EARLY_END}"])

# %%
# CV features (Coefficient of Variation): std / mean
# This captures "noisiness" relative to the signal level.

eps = 1e-9

cv = summary[["clone_id"]].copy()
for m in metrics:
    cv[f"{m}_cv"] = summary[f"{m}_std"] / (summary[f"{m}_mean"] + eps)

cv.head()
# Out:
#      clone_id  titer_cv    vcd_cv  viability_cv  aggregation_cv
# 0  CLONE_0001  0.069784  0.052391      0.019119        0.026472
# 1  CLONE_0002  0.121116  0.072490      0.012693        0.048463
# 2  CLONE_0003  0.075887  0.071840      0.025316        0.109903
# 3  CLONE_0004  0.269105  0.078209      0.013559        0.381364
# 4  CLONE_0005  0.075467  0.113296      0.017274        0.066114

# %%
# We want one culture_mode per clone.
# process_condition is per passage_id, so we join with passage to get clone_id.

mode_df = pd.read_sql_query("""
SELECT p.clone_id, pc.culture_mode
FROM process_condition pc
JOIN passage p ON p.passage_id = pc.passage_id
""", conn)

# If culture_mode varies across passages (rare in our simulator), take the most frequent mode per clone
mode_major = (
    mode_df.groupby(["clone_id", "culture_mode"]).size().reset_index(name="n")
    .sort_values(["clone_id", "n"], ascending=[True, False])
    .drop_duplicates("clone_id")[["clone_id", "culture_mode"]]
)

# One-hot encode (fed-batch/perfusion)
mode_ohe = pd.get_dummies(mode_major["culture_mode"], prefix="culture_mode")
mode_features = pd.concat([mode_major[["clone_id"]], mode_ohe], axis=1)

mode_features.head()
# Out:
#      clone_id  culture_mode_fed-batch  culture_mode_perfusion
# 0  CLONE_0001                    True                   False
# 1  CLONE_0002                    True                   False
# 2  CLONE_0003                    True                   False
# 3  CLONE_0004                   False                    True
# 4  CLONE_0005                    True                   False

# %%
X_v2 = summary.merge(slopes, on="clone_id", how="left") \
              .merge(last_df, on="clone_id", how="left") \
              .merge(splits, on="clone_id", how="left") \
              .merge(qp, on="clone_id", how="left") \
              .merge(cv, on="clone_id", how="left") \
              .merge(mode_features, on="clone_id", how="left") \
              .merge(ddpcr, on="clone_id", how="left")

print("X_v2 shape:", X_v2.shape)
X_v2.head()
# Out:
# X_v2 shape: (5000, 46)
#      clone_id  titer_mean  titer_std  titer_min  titer_max      vcd_mean  \
# 0  CLONE_0001    3.142136   0.219271   2.698838   3.439919  1.083374e+07
# 1  CLONE_0002    0.904944   0.109603   0.803284   1.141559  1.480237e+07
# 2  CLONE_0003    5.045860   0.382916   4.372261   5.533843  8.915354e+06
# 3  CLONE_0004    1.354368   0.364467   0.587097   1.712960  1.422009e+07
# 4  CLONE_0005    3.365629   0.253995   3.046187   3.803560  1.080455e+07
#
#         vcd_std       vcd_min       vcd_max  viability_mean  ...  \
# 0  5.675920e+05  1.013179e+07  1.192629e+07       94.797460  ...
# 1  1.073024e+06  1.360551e+07  1.648285e+07       95.662931  ...
# 2  6.404794e+05  7.768218e+06  9.791953e+06       93.506606  ...
# 3  1.112143e+06  1.266285e+07  1.564230e+07       95.995496  ...
# 4  1.224111e+06  9.122992e+06  1.251044e+07       94.013308  ...
#
#    aggregation_curvature       qP_mean        qP_p10  titer_cv    vcd_cv  \
# 0               0.030381  2.900326e-07  2.631328e-07  0.069784  0.052391
# 1               0.102646  6.113507e-08  7.474889e-08  0.121116  0.072490
# 2               0.278685  5.659741e-07  6.163784e-07  0.075887  0.071840
# 3              -0.032303  9.524324e-08  3.753267e-08  0.269105  0.078209
# 4               0.108220  3.115010e-07  2.884335e-07  0.075467  0.113296
#
#    viability_cv  aggregation_cv  culture_mode_fed-batch  \
# 0      0.019119        0.026472                    True
# 1      0.012693        0.048463                    True
# 2      0.025316        0.109903                    True
# 3      0.013559        0.381364                   False
# 4      0.017274        0.066114                    True
#
#    culture_mode_perfusion  ddpcr_cn
# 0                   False       4.0
# 1                   False       2.0
# 2                   False       5.0
# 3                    True       4.0
# 4                   False       6.0
#
# [5 rows x 46 columns]

# %%
X_v2[["ddpcr_cn"]].isna().mean()
# Out:
# ddpcr_cn    0.0
# dtype: float64

# %%
y = pd.read_sql_query("""
SELECT clone_id, productivity_drop_pct
FROM stability_test
""", conn)

dataset_v2 = X_v2.merge(y, on="clone_id", how="inner")
print("dataset_v2 shape:", dataset_v2.shape)
dataset_v2.head()
# Out:
# dataset_v2 shape: (5000, 47)
#      clone_id  titer_mean  titer_std  titer_min  titer_max      vcd_mean  \
# 0  CLONE_0001    3.142136   0.219271   2.698838   3.439919  1.083374e+07
# 1  CLONE_0002    0.904944   0.109603   0.803284   1.141559  1.480237e+07
# 2  CLONE_0003    5.045860   0.382916   4.372261   5.533843  8.915354e+06
# 3  CLONE_0004    1.354368   0.364467   0.587097   1.712960  1.422009e+07
# 4  CLONE_0005    3.365629   0.253995   3.046187   3.803560  1.080455e+07
#
#         vcd_std       vcd_min       vcd_max  viability_mean  ...  \
# 0  5.675920e+05  1.013179e+07  1.192629e+07       94.797460  ...
# 1  1.073024e+06  1.360551e+07  1.648285e+07       95.662931  ...
# 2  6.404794e+05  7.768218e+06  9.791953e+06       93.506606  ...
# 3  1.112143e+06  1.266285e+07  1.564230e+07       95.995496  ...
# 4  1.224111e+06  9.122992e+06  1.251044e+07       94.013308  ...
#
#         qP_mean        qP_p10  titer_cv    vcd_cv  viability_cv  \
# 0  2.900326e-07  2.631328e-07  0.069784  0.052391      0.019119
# 1  6.113507e-08  7.474889e-08  0.121116  0.072490      0.012693
# 2  5.659741e-07  6.163784e-07  0.075887  0.071840      0.025316
# 3  9.524324e-08  3.753267e-08  0.269105  0.078209      0.013559
# 4  3.115010e-07  2.884335e-07  0.075467  0.113296      0.017274
#
#    aggregation_cv  culture_mode_fed-batch  culture_mode_perfusion  ddpcr_cn  \
# 0        0.026472                    True                   False       4.0
# 1        0.048463                    True                   False       2.0
# 2        0.109903                    True                   False       5.0
# 3        0.381364                   False                    True       4.0
# 4        0.066114                    True                   False       6.0
#
#    productivity_drop_pct
# 0               0.371476
# 1               0.218365
# 2               0.472004
# 3               0.832703
# 4               0.344950
#
# [5 rows x 47 columns]

# %%
# Optional sanity check: missing rate per column
dataset_v2.isna().mean().sort_values(ascending=False).head(15)
# Out:
# clone_id                  0.0
# aggregation_slope_7_10    0.0
# titer_slope_7_10          0.0
# titer_curvature           0.0
# vcd_slope_3_6             0.0
# vcd_slope_7_10            0.0
# vcd_curvature             0.0
# viability_slope_3_6       0.0
# viability_slope_7_10      0.0
# viability_curvature       0.0
# aggregation_slope_3_6     0.0
# aggregation_curvature     0.0
# aggregation_p10           0.0
# qP_mean                   0.0
# qP_p10                    0.0
# dtype: float64

# %%
dataset_v2[["culture_mode_fed-batch", "culture_mode_perfusion"]].mean()
# Out:
# culture_mode_fed-batch    0.8546
# culture_mode_perfusion    0.1454
# dtype: float64

# %%
OUT_DIR.mkdir(parents=True, exist_ok=True)

X_v2.to_csv(OUT_FEATURES, index=False)
dataset_v2.to_csv(OUT_LABELS, index=False)

print("Saved:")
print("-", OUT_FEATURES)
print("-", OUT_LABELS)
# Out:
# Saved:
# - ../data/synthetic/processed/cld_features_v2_5000_legacy.csv
# - ../data/synthetic/processed/cld_features_with_label_v2_5000_legacy.csv

# %%
conn.close()
print("DB connection closed.")
# Out:
# DB connection closed.
