# %% [markdown]
# # Notebook 02d — Feature Engineering v2 (Early time-series features)
#
# ## Goal
# Create a stronger clone-level feature table using early passages only (default: 3–10),
# with features that better capture early dynamics for predicting late outcomes.
#
# Compared to v1, we add:
# - last-value features (passage 10)
# - split-window slopes (3–6 vs 7–10)
# - curvature (slope change)
# - qP proxies (titer / VCD)
# - CV (std / mean)
#
# Outputs:
# - `data/synthetic/processed/cld_features_v2.csv`
# - `data/synthetic/processed/cld_features_with_label_v2.csv`

# %%
import sqlite3
import pandas as pd
import numpy as np
from pathlib import Path

DB_PATH = "../data/synthetic/raw/cld_2000clones_optimized.db"  # change to 500/2000/5000 as needed
conn = sqlite3.connect(DB_PATH)

print("Connected to:", DB_PATH)
# Out:
# Connected to: ../data/synthetic/raw/cld_2000clones_optimized.db

# %%
assay = pd.read_sql_query("""
SELECT 
  ar.assay_id,
  ar.assay_type,
  ar.value,
  ar.unit,
  ar.method,
  ar.batch_id,
  p.clone_id,
  p.passage_number,
  p.phase
FROM assay_result ar
JOIN passage p
  ON p.passage_id = ar.passage_id
""", conn)

assay.head()
# Out:
#                            assay_id   assay_type         value      unit  \
# 0        ASSAY_CLONE_0001_P01_titer        titer  4.368427e+00       g/L
# 1          ASSAY_CLONE_0001_P01_vcd          vcd  9.350325e+06  cells/mL
# 2    ASSAY_CLONE_0001_P01_viability    viability  9.474874e+01         %
# 3  ASSAY_CLONE_0001_P01_aggregation  aggregation  3.932117e+00         %
# 4        ASSAY_CLONE_0001_P02_titer        titer  4.286859e+00       g/L
#
#      method batch_id    clone_id  passage_number  phase
# 0     ELISA    B_P01  CLONE_0001               1  early
# 1   Vi-CELL    B_P01  CLONE_0001               1  early
# 2   Vi-CELL    B_P01  CLONE_0001               1  early
# 3  SEC-HPLC    B_P01  CLONE_0001               1  early
# 4     ELISA    B_P02  CLONE_0001               2  early

# %% [markdown]
# We exclude passage 1–2 due to frequent outlier behavior in real CLD.

# %%
EARLY_START = 3
EARLY_END = 10

assay_early = assay[(assay["passage_number"] >= EARLY_START) & (assay["passage_number"] <= EARLY_END)].copy()
print("Assay early rows:", len(assay_early))
assay_early.head()
# Out:
# Assay early rows: 66000
#                             assay_id   assay_type         value         unit  \
# 8         ASSAY_CLONE_0001_P03_titer        titer  4.182647e+00          g/L
# 9           ASSAY_CLONE_0001_P03_vcd          vcd  1.225314e+07     cells/mL
# 10    ASSAY_CLONE_0001_P03_viability    viability  9.316014e+01            %
# 11  ASSAY_CLONE_0001_P03_aggregation  aggregation  4.045568e+00            %
# 12     ASSAY_CLONE_0001_P03_ddpcr_cn     ddpcr_cn  3.000000e+00  copies/cell
#
#       method batch_id    clone_id  passage_number  phase
# 8      ELISA    B_P03  CLONE_0001               3  early
# 9    Vi-CELL    B_P03  CLONE_0001               3  early
# 10   Vi-CELL    B_P03  CLONE_0001               3  early
# 11  SEC-HPLC    B_P03  CLONE_0001               3  early
# 12     ddPCR    B_P03  CLONE_0001               3  early

# %%
# -----------------------------
# ddPCR copy number feature (clone-level)
# - ddpcr_cn is stored once per clone at passage = EARLY_START (e.g., 3)
# - We convert it to a single clone-level feature column: ddpcr_cn
# -----------------------------

ddpcr = assay_early[assay_early["assay_type"] == "ddpcr_cn"][["clone_id", "value"]].copy()
ddpcr = ddpcr.rename(columns={"value": "ddpcr_cn"})

# If multiple rows exist (shouldn't, but safe), take mean
ddpcr = ddpcr.groupby("clone_id", as_index=False)["ddpcr_cn"].mean()

print("ddPCR rows:", len(ddpcr))
ddpcr.head()
# Out:
# ddPCR rows: 2000
#      clone_id  ddpcr_cn
# 0  CLONE_0001       3.0
# 1  CLONE_0002       2.0
# 2  CLONE_0003       4.0
# 3  CLONE_0004       3.0
# 4  CLONE_0005       4.0

# %%
early_wide = assay_early.pivot_table(
    index=["clone_id", "passage_number"],
    columns="assay_type",
    values="value",
    aggfunc="mean"
).reset_index()

early_wide.head()
# Out:
# assay_type    clone_id  passage_number  aggregation  ddpcr_cn     titer  \
# 0           CLONE_0001               3     4.045568       3.0  4.182647
# 1           CLONE_0001               4     4.016309       NaN  4.438496
# 2           CLONE_0001               5     3.908363       NaN  4.319571
# 3           CLONE_0001               6     3.716915       NaN  4.170319
# 4           CLONE_0001               7     4.250356       NaN  4.284562
#
# assay_type           vcd  viability
# 0           1.225314e+07  93.160140
# 1           9.927389e+06  95.624552
# 2           1.152163e+07  93.658921
# 3           1.025110e+07  96.136083
# 4           1.108757e+07  96.698687

# %%
metrics = ["titer", "vcd", "viability", "aggregation"]

agg_dict = {m: ["mean", "std", "min", "max"] for m in metrics}

summary = early_wide.groupby("clone_id")[metrics].agg(agg_dict)
summary.columns = [f"{c[0]}_{c[1]}" for c in summary.columns]
summary = summary.reset_index()

summary.head()
# Out:
#      clone_id  titer_mean  titer_std  titer_min  titer_max      vcd_mean  \
# 0  CLONE_0001    4.157159   0.192816   3.860974   4.438496  1.078353e+07
# 1  CLONE_0002    1.157587   0.153671   0.947550   1.357355  1.380078e+07
# 2  CLONE_0003    6.755881   0.284146   6.495962   7.333870  7.967046e+06
# 3  CLONE_0004    0.855995   0.195139   0.633887   1.111325  1.499608e+07
# 4  CLONE_0005    3.645849   0.184313   3.385108   3.961007  1.148447e+07
#
#         vcd_std       vcd_min       vcd_max  viability_mean  viability_std  \
# 0  9.528191e+05  9.237027e+06  1.225314e+07       94.610357       1.330750
# 1  7.759186e+05  1.280831e+07  1.546131e+07       96.016350       1.534761
# 2  8.931379e+05  6.594390e+06  8.969199e+06       94.214253       1.850715
# 3  6.463732e+05  1.402751e+07  1.576869e+07       97.265204       1.334265
# 4  1.037870e+06  9.182657e+06  1.233431e+07       95.017839       1.768291
#
#    viability_min  viability_max  aggregation_mean  aggregation_std  \
# 0      93.160140      96.698687          4.026949         0.177485
# 1      92.720353      97.638680          2.841549         0.374993
# 2      90.923498      96.580426          5.714731         0.180837
# 3      95.497158      99.751185          7.089444         0.255451
# 4      92.813411      97.568084          1.094564         0.268014
#
#    aggregation_min  aggregation_max
# 0         3.716915         4.263244
# 1         2.046847         3.348793
# 2         5.549054         6.094516
# 3         6.740295         7.381527
# 4         0.599542         1.467408

# %%
def slope(x, y):
    if len(x) < 2:
        return np.nan
    return np.polyfit(x, y, 1)[0]

slope_rows = []
for clone_id, df in early_wide.groupby("clone_id"):
    x = df["passage_number"].values
    row = {"clone_id": clone_id}
    for m in metrics:
        row[f"{m}_slope"] = slope(x, df[m].values) if m in df.columns else np.nan
    slope_rows.append(row)

slopes = pd.DataFrame(slope_rows)
slopes.head()
# Out:
#      clone_id  titer_slope      vcd_slope  viability_slope  aggregation_slope
# 0  CLONE_0001    -0.060536 -163034.670347        -0.028760           0.026524
# 1  CLONE_0002    -0.046187  -92200.832828         0.119068           0.048264
# 2  CLONE_0003    -0.095438   32338.302181        -0.053376           0.026280
# 3  CLONE_0004    -0.013871   12142.115887         0.208350           0.054875
# 4  CLONE_0005    -0.029170  149585.529534         0.587294           0.005470

# %%
# last value at EARLY_END (e.g., p10)
last_df = early_wide[early_wide["passage_number"] == EARLY_END][["clone_id"] + metrics].copy()
last_df = last_df.rename(columns={m: f"{m}_p{EARLY_END}" for m in metrics})

last_df.head()
# Out:
# assay_type    clone_id  titer_p10       vcd_p10  viability_p10  \
# 7           CLONE_0001   3.980869  1.082152e+07      93.878839
# 15          CLONE_0002   0.959632  1.353893e+07      95.367503
# 23          CLONE_0003   6.495962  8.479243e+06      92.979930
# 31          CLONE_0004   0.638425  1.576869e+07      99.751185
# 39          CLONE_0005   3.711498  1.191803e+07      96.392499
#
# assay_type  aggregation_p10
# 7                  4.263244
# 15                 2.696899
# 23                 5.636752
# 31                 7.381527
# 39                 1.371695

# %%
def slope_in_window(df, m, start_p, end_p):
    d = df[(df["passage_number"] >= start_p) & (df["passage_number"] <= end_p)]
    if len(d) < 2 or m not in d.columns:
        return np.nan
    return slope(d["passage_number"].values, d[m].values)

split_rows = []
for clone_id, df in early_wide.groupby("clone_id"):
    row = {"clone_id": clone_id}
    for m in metrics:
        row[f"{m}_slope_{EARLY_START}_6"] = slope_in_window(df, m, EARLY_START, 6)
        row[f"{m}_slope_7_{EARLY_END}"] = slope_in_window(df, m, 7, EARLY_END)
        # curvature = change in slope (late - early)
        row[f"{m}_curvature"] = row[f"{m}_slope_7_{EARLY_END}"] - row[f"{m}_slope_{EARLY_START}_6"]
    split_rows.append(row)

splits = pd.DataFrame(split_rows)
splits.head()
# Out:
#      clone_id  titer_slope_3_6  titer_slope_7_10  titer_curvature  \
# 0  CLONE_0001        -0.015591         -0.106994        -0.091403
# 1  CLONE_0002        -0.044538         -0.132220        -0.087682
# 2  CLONE_0003        -0.223483         -0.032449         0.191034
# 3  CLONE_0004         0.045773         -0.034389        -0.080162
# 4  CLONE_0005        -0.183200         -0.035151         0.148049
#
#    vcd_slope_3_6  vcd_slope_7_10  vcd_curvature  viability_slope_3_6  \
# 0 -441188.655203  -273000.059549  168188.595653             0.696220
# 1 -428355.772425  -176101.394131  252254.378294             1.043691
# 2   19530.565709   547866.541762  528335.976053            -0.467636
# 3   82397.017632   164352.834565   81955.816933            -0.137461
# 4  324129.075469    12264.764725 -311864.310743             0.627700
#
#    viability_slope_7_10  viability_curvature  aggregation_slope_3_6  \
# 0             -0.827190            -1.523410              -0.109391
# 1             -0.493310            -1.537001               0.253476
# 2             -0.107083             0.360553               0.039156
# 3              1.186027             1.323488               0.171902
# 4              0.782613             0.154913              -0.053443
#
#    aggregation_slope_7_10  aggregation_curvature
# 0               -0.004323               0.105068
# 1               -0.061376              -0.314853
# 2                0.006228              -0.032928
# 3                0.076435              -0.095467
# 4               -0.085879              -0.032436

# %%
# qP proxy: titer / vcd
# add small epsilon to avoid division issues
eps = 1e-9

qp = summary[["clone_id"]].copy()
qp["qP_mean"] = summary["titer_mean"] / (summary["vcd_mean"] + eps)

# merge last values for p10
last_for_qp = last_df[["clone_id", f"titer_p{EARLY_END}", f"vcd_p{EARLY_END}"]].copy()
qp = qp.merge(last_for_qp, on="clone_id", how="left")

qp["qP_p10"] = qp[f"titer_p{EARLY_END}"] / (qp[f"vcd_p{EARLY_END}"] + eps)

# optional: drop the temporary columns
qp = qp.drop(columns=[f"titer_p{EARLY_END}", f"vcd_p{EARLY_END}"])

# %%
# CV features (Coefficient of Variation): std / mean
# This captures "noisiness" relative to the signal level.

eps = 1e-9

cv = summary[["clone_id"]].copy()
for m in metrics:
    cv[f"{m}_cv"] = summary[f"{m}_std"] / (summary[f"{m}_mean"] + eps)

cv.head()
# Out:
#      clone_id  titer_cv    vcd_cv  viability_cv  aggregation_cv
# 0  CLONE_0001  0.046382  0.088359      0.014066        0.044074
# 1  CLONE_0002  0.132751  0.056223      0.015984        0.131968
# 2  CLONE_0003  0.042059  0.112104      0.019644        0.031644
# 3  CLONE_0004  0.227968  0.043103      0.013718        0.036033
# 4  CLONE_0005  0.050554  0.090372      0.018610        0.244859

# %%
# We want one culture_mode per clone.
# process_condition is per passage_id, so we join with passage to get clone_id.

mode_df = pd.read_sql_query("""
SELECT p.clone_id, pc.culture_mode
FROM process_condition pc
JOIN passage p ON p.passage_id = pc.passage_id
""", conn)

# If culture_mode varies across passages (rare in our simulator), take the most frequent mode per clone
mode_major = (
    mode_df.groupby(["clone_id", "culture_mode"]).size().reset_index(name="n")
    .sort_values(["clone_id", "n"], ascending=[True, False])
    .drop_duplicates("clone_id")[["clone_id", "culture_mode"]]
)

# One-hot encode (fed-batch/perfusion)
mode_ohe = pd.get_dummies(mode_major["culture_mode"], prefix="culture_mode")
mode_features = pd.concat([mode_major[["clone_id"]], mode_ohe], axis=1)

mode_features.head()
# Out:
#      clone_id  culture_mode_fed-batch  culture_mode_perfusion
# 0  CLONE_0001                    True                   False
# 1  CLONE_0002                   False                    True
# 2  CLONE_0003                    True                   False
# 3  CLONE_0004                   False                    True
# 4  CLONE_0005                    True                   False

# %%
X_v2 = summary.merge(slopes, on="clone_id", how="left") \
              .merge(last_df, on="clone_id", how="left") \
              .merge(splits, on="clone_id", how="left") \
              .merge(qp, on="clone_id", how="left") \
              .merge(cv, on="clone_id", how="left") \
              .merge(mode_features, on="clone_id", how="left") \
              .merge(ddpcr, on="clone_id", how="left")

print("X_v2 shape:", X_v2.shape)
X_v2.head()
# Out:
# X_v2 shape: (2000, 46)
#      clone_id  titer_mean  titer_std  titer_min  titer_max      vcd_mean  \
# 0  CLONE_0001    4.157159   0.192816   3.860974   4.438496  1.078353e+07
# 1  CLONE_0002    1.157587   0.153671   0.947550   1.357355  1.380078e+07
# 2  CLONE_0003    6.755881   0.284146   6.495962   7.333870  7.967046e+06
# 3  CLONE_0004    0.855995   0.195139   0.633887   1.111325  1.499608e+07
# 4  CLONE_0005    3.645849   0.184313   3.385108   3.961007  1.148447e+07
#
#         vcd_std       vcd_min       vcd_max  viability_mean  ...  \
# 0  9.528191e+05  9.237027e+06  1.225314e+07       94.610357  ...
# 1  7.759186e+05  1.280831e+07  1.546131e+07       96.016350  ...
# 2  8.931379e+05  6.594390e+06  8.969199e+06       94.214253  ...
# 3  6.463732e+05  1.402751e+07  1.576869e+07       97.265204  ...
# 4  1.037870e+06  9.182657e+06  1.233431e+07       95.017839  ...
#
#    aggregation_curvature       qP_mean        qP_p10  titer_cv    vcd_cv  \
# 0               0.105068  3.855100e-07  3.678660e-07  0.046382  0.088359
# 1              -0.314853  8.387832e-08  7.087946e-08  0.132751  0.056223
# 2              -0.032928  8.479782e-07  7.661017e-07  0.042059  0.112104
# 3              -0.095467  5.708124e-08  4.048689e-08  0.227968  0.043103
# 4              -0.032436  3.174591e-07  3.114189e-07  0.050554  0.090372
#
#    viability_cv  aggregation_cv  culture_mode_fed-batch  \
# 0      0.014066        0.044074                    True
# 1      0.015984        0.131968                   False
# 2      0.019644        0.031644                    True
# 3      0.013718        0.036033                   False
# 4      0.018610        0.244859                    True
#
#    culture_mode_perfusion  ddpcr_cn
# 0                   False       3.0
# 1                    True       2.0
# 2                   False       4.0
# 3                    True       3.0
# 4                   False       4.0
#
# [5 rows x 46 columns]

# %%
X_v2[["ddpcr_cn"]].isna().mean()
# Out:
# ddpcr_cn    0.0
# dtype: float64

# %%
y = pd.read_sql_query("""
SELECT clone_id, productivity_drop_pct
FROM stability_test
""", conn)

dataset_v2 = X_v2.merge(y, on="clone_id", how="inner")
print("dataset_v2 shape:", dataset_v2.shape)
dataset_v2.head()
# Out:
# dataset_v2 shape: (2000, 47)
#      clone_id  titer_mean  titer_std  titer_min  titer_max      vcd_mean  \
# 0  CLONE_0001    4.157159   0.192816   3.860974   4.438496  1.078353e+07
# 1  CLONE_0002    1.157587   0.153671   0.947550   1.357355  1.380078e+07
# 2  CLONE_0003    6.755881   0.284146   6.495962   7.333870  7.967046e+06
# 3  CLONE_0004    0.855995   0.195139   0.633887   1.111325  1.499608e+07
# 4  CLONE_0005    3.645849   0.184313   3.385108   3.961007  1.148447e+07
#
#         vcd_std       vcd_min       vcd_max  viability_mean  ...  \
# 0  9.528191e+05  9.237027e+06  1.225314e+07       94.610357  ...
# 1  7.759186e+05  1.280831e+07  1.546131e+07       96.016350  ...
# 2  8.931379e+05  6.594390e+06  8.969199e+06       94.214253  ...
# 3  6.463732e+05  1.402751e+07  1.576869e+07       97.265204  ...
# 4  1.037870e+06  9.182657e+06  1.233431e+07       95.017839  ...
#
#         qP_mean        qP_p10  titer_cv    vcd_cv  viability_cv  \
# 0  3.855100e-07  3.678660e-07  0.046382  0.088359      0.014066
# 1  8.387832e-08  7.087946e-08  0.132751  0.056223      0.015984
# 2  8.479782e-07  7.661017e-07  0.042059  0.112104      0.019644
# 3  5.708124e-08  4.048689e-08  0.227968  0.043103      0.013718
# 4  3.174591e-07  3.114189e-07  0.050554  0.090372      0.018610
#
#    aggregation_cv  culture_mode_fed-batch  culture_mode_perfusion  ddpcr_cn  \
# 0        0.044074                    True                   False       3.0
# 1        0.131968                   False                    True       2.0
# 2        0.031644                    True                   False       4.0
# 3        0.036033                   False                    True       3.0
# 4        0.244859                    True                   False       4.0
#
#    productivity_drop_pct
# 0               0.178020
# 1               0.173411
# 2               0.207761
# 3               0.230650
# 4               0.300369
#
# [5 rows x 47 columns]

# %%
# Optional sanity check: missing rate per column
dataset_v2.isna().mean().sort_values(ascending=False).head(15)
# Out:
# clone_id                  0.0
# aggregation_slope_7_10    0.0
# titer_slope_7_10          0.0
# titer_curvature           0.0
# vcd_slope_3_6             0.0
# vcd_slope_7_10            0.0
# vcd_curvature             0.0
# viability_slope_3_6       0.0
# viability_slope_7_10      0.0
# viability_curvature       0.0
# aggregation_slope_3_6     0.0
# aggregation_curvature     0.0
# aggregation_p10           0.0
# qP_mean                   0.0
# qP_p10                    0.0
# dtype: float64

# %%
dataset_v2[["culture_mode_fed-batch", "culture_mode_perfusion"]].mean()
# Out:
# culture_mode_fed-batch    0.87
# culture_mode_perfusion    0.13
# dtype: float64

# %%
OUT_DIR = Path("../data/synthetic/processed")
OUT_DIR.mkdir(parents=True, exist_ok=True)

X_v2.to_csv(OUT_DIR / "cld_features_v2_optimized.csv", index=False)
dataset_v2.to_csv(OUT_DIR / "cld_features_with_label_v2_optimized.csv", index=False)

print("Saved:")
print("-", OUT_DIR / "cld_features_v2_optimized.csv")
print("-", OUT_DIR / "cld_features_with_label_v2_optimized.csv")
# Out:
# Saved:
# - ../data/synthetic/processed/cld_features_v2_optimized.csv
# - ../data/synthetic/processed/cld_features_with_label_v2_optimized.csv

# %%
conn.close()
print("DB connection closed.")
# Out:
# DB connection closed.
