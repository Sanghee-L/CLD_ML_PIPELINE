# %% [markdown]
# # Notebook 03b - Multi-target Models for CLD (Early -> Late Prediction)
#
# ## Goal
# Train separate regression models that predict late-stage outcomes using **early-only features**:
# - Stability: productivity_drop_pct (lower is better)
# - Productivity: late_mean_titer (higher is better)
# - Quality: late_mean_aggregation (lower is better)
#
# These predicted values will be used in Notebook 04 to perform **predicted-late-based clone selection**, wihch mirrors real CLD projects where late data is not available at decision time.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from scipy.stats import spearmanr
from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score

# %%
scenario = "legacy"  # or "legacy"

DATA_PATH = Path("../data/synthetic/processed") / f"cld_features_with_labels_3targets_v2_24_30_5000_{scenario}.csv"
print("Loading:", DATA_PATH)

df = pd.read_csv(DATA_PATH)
df.head()
# Out:
# Loading: ../data/synthetic/processed/cld_features_with_labels_3targets_v2_24_30_5000_legacy.csv
#      clone_id  titer_mean  titer_std  titer_min  titer_max      vcd_mean  \
# 0  CLONE_0001    3.142136   0.219271   2.698838   3.439919  1.083374e+07
# 1  CLONE_0002    0.904944   0.109603   0.803284   1.141559  1.480237e+07
# 2  CLONE_0003    5.045860   0.382916   4.372261   5.533843  8.915354e+06
# 3  CLONE_0004    1.354368   0.364467   0.587097   1.712960  1.422009e+07
# 4  CLONE_0005    3.365629   0.253995   3.046187   3.803560  1.080455e+07
#
#         vcd_std       vcd_min       vcd_max  viability_mean  ...  titer_cv  \
# 0  5.675920e+05  1.013179e+07  1.192629e+07       94.797460  ...  0.069784
# 1  1.073024e+06  1.360551e+07  1.648285e+07       95.662931  ...  0.121116
# 2  6.404794e+05  7.768218e+06  9.791953e+06       93.506606  ...  0.075887
# 3  1.112143e+06  1.266285e+07  1.564230e+07       95.995496  ...  0.269105
# 4  1.224111e+06  9.122992e+06  1.251044e+07       94.013308  ...  0.075467
#
#      vcd_cv  viability_cv  aggregation_cv  culture_mode_fed-batch  \
# 0  0.052391      0.019119        0.026472                    True
# 1  0.072490      0.012693        0.048463                    True
# 2  0.071840      0.025316        0.109903                    True
# 3  0.078209      0.013559        0.381364                   False
# 4  0.113296      0.017274        0.066114                    True
#
#    culture_mode_perfusion  ddpcr_cn  productivity_drop_pct  late_mean_titer  \
# 0                   False       4.0               0.371476         2.064437
# 1                   False       2.0               0.218365         0.704085
# 2                   False       5.0               0.472004         2.759155
# 3                    True       4.0               0.832703         0.241370
# 4                   False       6.0               0.344950         2.230768
#
#    late_mean_aggregation
# 0               6.333889
# 1               7.144205
# 2               2.610875
# 3               1.842977
# 4               2.949963
#
# [5 rows x 49 columns]

# %%
# Prepare X and 3 targets
targets = ["productivity_drop_pct", "late_mean_titer", "late_mean_aggregation"]

# Important: fix row order first
df = df.sort_values("clone_id").reset_index(drop=True)

clone_ids = df["clone_id"].copy()

X = df.drop(columns=["clone_id"] + targets).copy()
X = X.fillna(X.median(numeric_only=True))

y_drop  = df["productivity_drop_pct"].copy().clip(lower=0.0, upper=1.0)
y_titer = df["late_mean_titer"].copy()
y_agg   = df["late_mean_aggregation"].copy().clip(lower=0.0, upper=100.0)

print("X shape:", X.shape)
print("Targets:", y_drop.shape, y_titer.shape, y_agg.shape)
# Out:
# X shape: (5000, 45)
# Targets: (5000,) (5000,) (5000,)

# %%
# Split by row index to guarantee alignment
idx = np.arange(len(df))
train_idx, test_idx = train_test_split(idx, test_size=0.2, random_state=42, shuffle=True)

X_train = X.iloc[train_idx].copy()
X_test  = X.iloc[test_idx].copy()

id_train = clone_ids.iloc[train_idx].values
id_test  = clone_ids.iloc[test_idx].values

y_drop_train  = y_drop.iloc[train_idx].values
y_drop_test   = y_drop.iloc[test_idx].values

y_titer_train = y_titer.iloc[train_idx].values
y_titer_test  = y_titer.iloc[test_idx].values

y_agg_train   = y_agg.iloc[train_idx].values
y_agg_test    = y_agg.iloc[test_idx].values

print("Train size:", len(train_idx), "Test size:", len(test_idx))
# Out:
# Train size: 4000 Test size: 1000

# %%
# Train 3 Random Forest models, one for each target

def fit_rf(X_train, y_train):
    model = RandomForestRegressor(
        n_estimators=600,
        random_state=42,
        min_samples_leaf=5,
        max_features="sqrt"
    )
    model.fit(X_train, y_train)
    return model

rf_drop = fit_rf(X_train, y_drop_train)
rf_titer = fit_rf(X_train, y_titer_train)
rf_agg = fit_rf(X_train, y_agg_train)

# %%
# Evaluate models on test set

def eval_model(name, model, X_test, y_test):
    pred = model.predict(X_test)
    mae = mean_absolute_error(y_test, pred)
    r2 = r2_score(y_test, pred)
    print(f"{name:18s}  MAE={mae:.4f}   R2={r2:.4f}")
    return pred

pred_drop = eval_model("drop (stability)", rf_drop, X_test, y_drop_test)
pred_titer = eval_model("late_titer", rf_titer, X_test, y_titer_test)
pred_agg = eval_model("late_agg", rf_agg, X_test, y_agg_test)
# Out:
# drop (stability)    MAE=0.0939   R2=0.5277
# late_titer          MAE=0.2347   R2=0.8765
# late_agg            MAE=0.1527   R2=0.9943

# %% [markdown]
# ## Auxiliary classifiers: super clone / aggressive clone
#
# We train two additional classifiers using the same early features:
#
# - `is_super`: rare commercial winner (high P + high S + sustained late performance)
# - `is_aggressive`: attractive early false positive (good early productivity, weak stability later)
#
# Why do this?
# - The regression models predict late continuous targets
# - But the subgroup labels capture biologically meaningful latent regimes
# - These classifiers can later be combined into a decision rule:
#   - prefer high super probability
#   - avoid high aggressive probability

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score, average_precision_score

# Load latent truth labels
LATENT_PATH = Path(f"../data/synthetic/raw/clone_latent_truths_5000_{scenario}.csv")
lat = pd.read_csv(LATENT_PATH)[["clone_id", "is_super", "is_aggressive"]]

# Align labels to the same sorted df used above
label_df = df[["clone_id"]].merge(lat, on="clone_id", how="left")
label_df[["is_super", "is_aggressive"]] = label_df[["is_super", "is_aggressive"]].fillna(0).astype(int)

y_super = label_df["is_super"].copy()
y_aggr  = label_df["is_aggressive"].copy()

# Use the SAME train/test indices as the regression models
y_super_train = y_super.iloc[train_idx].values
y_super_test  = y_super.iloc[test_idx].values

y_aggr_train = y_aggr.iloc[train_idx].values
y_aggr_test  = y_aggr.iloc[test_idx].values

print("Super prevalence (train/test):", y_super_train.mean(), y_super_test.mean())
print("Aggressive prevalence (train/test):", y_aggr_train.mean(), y_aggr_test.mean())
# Out:
# Super prevalence (train/test): 0.01625 0.014
# Aggressive prevalence (train/test): 0.03725 0.039

# %% [markdown]
# ### Evaluate the subgroup classifiers
#
# We use:
# - ROC-AUC: ranking quality of probabilities
# - Average Precision (AP): more informative under class imbalance
# - Top-K capture rate: among the clones with highest predicted subgroup probability,
#   how many are truly from that subgroup?

# %%
# Train classifiers
def fit_rf_clf(X_train, y_train):
    clf = RandomForestClassifier(
        n_estimators=600,
        random_state=42,
        min_samples_leaf=5,
        max_features="sqrt",
        class_weight="balanced_subsample"
    )
    clf.fit(X_train, y_train)
    return clf

rf_super = fit_rf_clf(X_train, y_super_train)
rf_aggr  = fit_rf_clf(X_train, y_aggr_train)

pred_super_prob = rf_super.predict_proba(X_test)[:, 1]
pred_aggr_prob  = rf_aggr.predict_proba(X_test)[:, 1]

# %%
def eval_binary_clf(name, y_true, y_prob, k_list=[5, 10, 20, 50]):
    print(f"\n=== {name} ===")
    print("Prevalence:", float(np.mean(y_true)))

    # ROC-AUC / AP only valid if both classes exist in test
    if len(np.unique(y_true)) == 2:
        print("ROC-AUC:", float(roc_auc_score(y_true, y_prob)))
        print("Average Precision:", float(average_precision_score(y_true, y_prob)))
    else:
        print("ROC-AUC: n/a (single class in test)")
        print("Average Precision: n/a (single class in test)")

    rows = []
    order = np.argsort(-y_prob)
    for k in k_list:
        top_idx = order[:k]
        capture = float(np.mean(y_true[top_idx]))
        rows.append({"k": k, "capture_rate": capture})
    out = pd.DataFrame(rows)
    display(out)
    return out

super_capture = eval_binary_clf("Super classifier", y_super_test, pred_super_prob)
aggr_capture  = eval_binary_clf("Aggressive classifier", y_aggr_test, pred_aggr_prob)
# Out:
# === Super classifier ===
# Prevalence: 0.014
# ROC-AUC: 0.9873225152129818
# Average Precision: 0.6198379019979233
#     k  capture_rate
# 0   5          0.80
# 1  10          0.50
# 2  20          0.50
# 3  50          0.24
# === Aggressive classifier ===
# Prevalence: 0.039
# ROC-AUC: 0.9723845353397903
# Average Precision: 0.855514667936965
#     k  capture_rate
# 0   5          1.00
# 1  10          1.00
# 2  20          1.00
# 3  50          0.64

# %%
# Save predictions to CSV

pred_table = pd.DataFrame({
    "clone_id": id_test,
    "true_drop": y_drop_test,
    "pred_drop": pred_drop,
    "true_late_titer": y_titer_test,
    "pred_late_titer": pred_titer,
    "true_late_agg": y_agg_test,
    "pred_late_agg": pred_agg,
    "true_is_super": y_super_test,
    "pred_super_prob": pred_super_prob,
    "true_is_aggressive": y_aggr_test,
    "pred_aggressive_prob": pred_aggr_prob,
})

OUT_PRED = Path("../data/synthetic/processed") / f"predictions_testset_3targets_{scenario}.csv"
pred_table.to_csv(OUT_PRED, index=False)
print("Saved:", OUT_PRED)

df_eval = pred_table.copy()
df_eval.head()
# Out:
# Saved: ../data/synthetic/processed/predictions_testset_3targets_legacy.csv
#      clone_id  true_drop  pred_drop  true_late_titer  pred_late_titer  \
# 0  CLONE_1502   0.317077   0.340914         0.545697         0.480192
# 1  CLONE_2587   0.578690   0.323446         0.765624         1.225776
# 2  CLONE_2654   0.145306   0.395013         0.542382         0.421447
# 3  CLONE_1056   0.328961   0.351405         1.052172         1.037830
# 4  CLONE_0706   0.532707   0.541470         2.108592         2.276690
#
#    true_late_agg  pred_late_agg  true_is_super  pred_super_prob  \
# 0       9.255182       9.129396              0         0.004664
# 1       2.705430       2.896381              0         0.001644
# 2       7.790259       7.892301              0         0.002980
# 3       7.163981       7.441450              0         0.006100
# 4       9.052010       9.072148              0         0.009336
#
#    true_is_aggressive  pred_aggressive_prob
# 0                   0              0.005698
# 1                   0              0.000000
# 2                   0              0.016608
# 3                   0              0.001589
# 4                   0              0.070610

# %%
# --- Spearman + TopK evaluation ---
# If scipy is available, use it. If not, fallback to pandas rank corr.
try:
    from scipy.stats import spearmanr
    def spearman(a, b):
        return spearmanr(a, b).correlation
except Exception:
    def spearman(a, b):
        return pd.Series(a).rank().corr(pd.Series(b).rank())

def topk_overlap(true_scores, pred_scores, k):
    """
    Returns overlap fraction between true top-k and predicted top-k sets.
    """
    true_top = set(pd.Series(true_scores).nlargest(k).index)
    pred_top = set(pd.Series(pred_scores).nlargest(k).index)
    return len(true_top & pred_top) / k

def topk_recall_of_true_good(pred_rank, true_good_mask, k):
    """
    Among predicted top-k, what fraction are truly good?
    """
    top_idx = pred_rank.nlargest(k).index
    return true_good_mask.loc[top_idx].mean()

df_eval = pred_table.copy()

# 1) Spearman correlations (ranking quality)
# For drop: lower is better, so we correlate (-drop) to keep "higher is better" convention
print("=== Spearman (ranking correlation) ===")
print("drop (lower better):", spearman(-df_eval["true_drop"], -df_eval["pred_drop"]))
print("late_titer (higher better):", spearman(df_eval["true_late_titer"], df_eval["pred_late_titer"]))
print("late_agg (lower better):", spearman(-df_eval["true_late_agg"], -df_eval["pred_late_agg"]))

# 2) Define a "true goodness" utility for evaluation (synthetic world has true late)
# This is *evaluation only* (offline). In real projects we won't have true late at decision time.
def z(s):
    return (s - s.mean()) / (s.std(ddof=0) + 1e-9)

# weights for evaluation utility (tune if you want)
A_TITER = 1.0
B_DROP  = 1.0
C_AGG   = 0.5

df_eval["true_utility"] = (
    A_TITER * z(df_eval["true_late_titer"])
    - B_DROP * z(df_eval["true_drop"])
    - C_AGG * z(df_eval["true_late_agg"])
)

df_eval["pred_utility"] = (
    A_TITER * z(df_eval["pred_late_titer"])
    - B_DROP * z(df_eval["pred_drop"])
    - C_AGG * z(df_eval["pred_late_agg"])
)

# 3) Top-K overlap and precision-like metrics for decisions
K_LIST = [5, 10, 20, 50]  # adjust to your CLD stage size

print("\n=== Top-K evaluation using utility ===")
for k in K_LIST:
    overlap = topk_overlap(df_eval["true_utility"], df_eval["pred_utility"], k)
    print(f"Top-{k} overlap (true vs pred utility): {overlap:.3f}")

# 4) Top-K "true-good" rate among predicted top-k
# Define "true good" clones as the top X% by true_utility (offline definition)
GOOD_FRAC = 0.10
good_threshold = df_eval["true_utility"].quantile(1 - GOOD_FRAC)
df_eval["true_good"] = df_eval["true_utility"] >= good_threshold

print("\n=== Top-K true-good rate among predicted picks ===")
pred_rank = df_eval["pred_utility"]
for k in K_LIST:
    rate = topk_recall_of_true_good(pred_rank, df_eval["true_good"], k)
    print(f"Predicted top-{k}: fraction that are truly top {int(GOOD_FRAC*100)}% good = {rate:.3f}")
# Out:
# === Spearman (ranking correlation) ===
# drop (lower better): 0.627363899245991
# late_titer (higher better): 0.9650233370233371
# late_agg (lower better): 0.997844281844282
#
# === Top-K evaluation using utility ===
# Top-5 overlap (true vs pred utility): 0.600
# Top-10 overlap (true vs pred utility): 0.800
# Top-20 overlap (true vs pred utility): 0.800
# Top-50 overlap (true vs pred utility): 0.700
#
# === Top-K true-good rate among predicted picks ===
# Predicted top-5: fraction that are truly top 10% good = 1.000
# Predicted top-10: fraction that are truly top 10% good = 1.000
# Predicted top-20: fraction that are truly top 10% good = 1.000
# Predicted top-50: fraction that are truly top 10% good = 0.860

# %% [markdown]
# ## A) Define two utility modes (business objectives)
#
# We evaluate two different "success definitions" depending on business goals:
#
# ### 1) Biosimilar / commercial volume mode
# - Prioritize **high productivity** (late titer ↑)
# - Prioritize **stability** (drop ↓)
# - Quality (aggregation) matters, but is a **lower weight**
#
# ### 2) Novel / ADC / high-quality mode
# - Prioritize **quality** (aggregation ↓) more strongly
# - Still require productivity and stability, but quality has higher weight
#
# We compute utility from **true late outcomes** ("offline evaluation") and also from **predicted late outcomes** ("model-based ranking").

# %%
def z(s: pd.Series) -> pd.Series:
    s = s.astype(float)
    return (s - s.mean()) / (s.std(ddof=0) + 1e-9)

# ---- Required columns in df_eval (test-set prediction table) ----
required = ["true_drop", "pred_drop", "true_late_titer", "pred_late_titer", "true_late_agg", "pred_late_agg"]
missing = [c for c in required if c not in df_eval.columns]
if missing:
    raise ValueError(f"df_eval is missing required columns: {missing}. "
                     f"Make sure 03b created df_eval with true/pred targets.")

# ---- Utility weights ----
# Biosimilar: productivity + stability dominate
W_BIO = dict(titer=1.0, drop=1.0, agg=0.2)

# Novel/ADC: quality gets larger weight
W_NOVEL = dict(titer=1.0, drop=1.0, agg=1.0)

def compute_utility(df: pd.DataFrame, weights: dict, prefix: str) -> pd.Series:
    return (
        weights["titer"] * z(df[f"{prefix}_late_titer"])
        - weights["drop"] * z(df[f"{prefix}_drop"])
        - weights["agg"] * z(df[f"{prefix}_late_agg"])
    )

# Create z-score utilities (true vs predicted) for both modes
df_eval["true_util_bio"]   = compute_utility(df_eval, W_BIO,   "true")
df_eval["pred_util_bio"]   = compute_utility(df_eval, W_BIO,   "pred")

df_eval["true_util_novel"] = compute_utility(df_eval, W_NOVEL, "true")
df_eval["pred_util_novel"] = compute_utility(df_eval, W_NOVEL, "pred")

df_eval[["true_util_bio","pred_util_bio","true_util_novel","pred_util_novel"]].head()
# Out:
#    true_util_bio  pred_util_bio  true_util_novel  pred_util_novel
# 0      -0.552228      -0.744543        -1.411772        -1.579497
# 1      -1.441993       0.314783        -0.406907         1.311424
# 2       0.516322      -1.167137         0.080533        -1.638565
# 3      -0.225710      -0.378966        -0.480338        -0.717911
# 4      -1.001151      -1.436293        -1.801923        -2.254424

# %% [markdown]
# ## B) Redefine "bottom-right" using utility (top-X% elite)
#
# The traditional CLD "bottom-right" uses two thresholds:
# - late_titer in the top quantile (e.g., Q90)
# - drop in the bottom quantile (e.g., Q10)
#
# However, our CLD decision is **multi-objective** (titer + stability + quality).
# So we redefine "bottom-right" as:
#
# > **Elite set = top X% by true utility**
#
# We compute elite sets for:
# - Biosimilar utility mode
# - Novel/ADC utility mode
#
# This makes evaluation consistent with how we will later rank clones.

# %%
# Elite definitions by utility
GOOD_FRAC_LIST = [0.10, 0.05, 0.02, 0.01]   # top 10%, 5%, 2%, 1%

def mark_elite(df: pd.DataFrame, util_col: str, frac: float, out_col: str):
    thr = df[util_col].quantile(1 - frac)
    df[out_col] = (df[util_col] >= thr).astype(int)
    return thr

elite_thresholds = []

for frac in GOOD_FRAC_LIST:
    pct = int(frac * 100)

    thr_bio = mark_elite(df_eval, "true_util_bio", frac, f"elite_bio_{pct}")
    thr_nov = mark_elite(df_eval, "true_util_novel", frac, f"elite_novel_{pct}")

    elite_thresholds.append({
        "frac": frac,
        "thr_true_util_bio": float(thr_bio),
        "thr_true_util_novel": float(thr_nov),
        "n_elite_bio": int(df_eval[f"elite_bio_{pct}"].sum()),
        "n_elite_novel": int(df_eval[f"elite_novel_{pct}"].sum()),
    })

elite_thresholds_df = pd.DataFrame(elite_thresholds)
elite_thresholds_df
# Out:
#    frac  thr_true_util_bio  thr_true_util_novel  n_elite_bio  n_elite_novel
# 0  0.10           1.544963             2.105006          100            100
# 1  0.05           2.030098             2.606897           50             50
# 2  0.02           2.988395             3.427439           20             20
# 3  0.01           4.128951             3.982508           10             10

# %% [markdown]
# ## C) Dominance + Top-K capture comparison (biosimilar vs novel)
#
# We compare how well predicted utilities recover elite clones under two modes:
#
# ### Metrics
# 1) **Spearman**: ranking correlation between true utility and predicted utility
# 2) **Top-K overlap**: how many of the predicted top-K are also in true top-K (strict)
# 3) **Top-K elite rate**: among predicted top-K, what fraction are in the true elite set (practical)
# 4) **Subgroup capture** (if available): super/aggressive fractions among predicted top-K
#
# This mirrors real CLD decision making:
# - You keep only a small Top-K set for late-stage validation.

# %%
from scipy.stats import spearmanr

K_LIST = [5, 10, 20, 50]

def topk_overlap(true_score: pd.Series, pred_score: pd.Series, k: int) -> float:
    true_top = set(true_score.sort_values(ascending=False).head(k).index)
    pred_top = set(pred_score.sort_values(ascending=False).head(k).index)
    return len(true_top & pred_top) / k

def elite_rate_in_topk(df: pd.DataFrame, pred_util_col: str, elite_col: str, k: int) -> float:
    top = df.sort_values(pred_util_col, ascending=False).head(k)
    return float(top[elite_col].mean())

def subgroup_rates_in_topk(df: pd.DataFrame, pred_util_col: str, k: int):
    top = df.sort_values(pred_util_col, ascending=False).head(k)
    out = {}
    if "is_super" in top.columns:
        out["super_rate"] = float(top["is_super"].mean())
    if "is_aggressive" in top.columns:
        out["aggressive_rate"] = float(top["is_aggressive"].mean())
    return out

def eval_mode(mode_name: str, true_util: str, pred_util: str, elite_col: str):
    print(f"\n==================== {mode_name} ====================")
    # Spearman (ranking)
    rho = spearmanr(df_eval[true_util], df_eval[pred_util]).correlation
    print("Spearman(true_util vs pred_util):", rho)

    rows = []
    for k in K_LIST:
        rows.append({
            "mode": mode_name,
            "k": k,
            "topk_overlap": topk_overlap(df_eval[true_util], df_eval[pred_util], k),
            "elite_rate_in_topk": elite_rate_in_topk(df_eval, pred_util, elite_col, k),
            **subgroup_rates_in_topk(df_eval, pred_util, k),
        })

    out = pd.DataFrame(rows)
    display(out)
    return out

# Evaluate both modes at elite top-10% (you can change to elite_bio_5 / elite_bio_1, etc.)
res_bio = eval_mode(
    "Biosimilar mode (elite = top10%)",
    true_util = "true_util_bio",
    pred_util = "pred_util_bio",
    elite_col = "elite_bio_10",
)

res_novel = eval_mode(
    "Novel/ADC mode (elite = top10%)",
    true_util = "true_util_novel",
    pred_util = "pred_util_novel",
    elite_col = "elite_novel_10",
)

res_bio_2 = eval_mode(
    "Biosimilar mode (elite = top2%)",
    true_util ='true_util_bio',
    pred_util = "pred_util_bio",
    elite_col = "elite_bio_2" 
)

res_novel_2 = eval_mode(
    "Novel/ADC mode (elite = top2%)",
    true_util = "true_util_novel",
    pred_util = "pred_util_novel",
    elite_col = "elite_novel_2"
)


# Combine results for side-by-side viewing
results_compare = pd.concat([res_bio, res_novel, res_bio_2, res_novel_2], 
                            ignore_index=True)
results_compare
# Out:
# ==================== Biosimilar mode (elite = top10%) ====================
# Spearman(true_util vs pred_util): 0.7664165144165145
#                                mode   k  topk_overlap  elite_rate_in_topk
# 0  Biosimilar mode (elite = top10%)   5          0.60                1.00
# 1  Biosimilar mode (elite = top10%)  10          0.80                1.00
# 2  Biosimilar mode (elite = top10%)  20          0.75                1.00
# 3  Biosimilar mode (elite = top10%)  50          0.76                0.88
# ==================== Novel/ADC mode (elite = top10%) ====================
# Spearman(true_util vs pred_util): 0.8611812211812212
#                               mode   k  topk_overlap  elite_rate_in_topk
# 0  Novel/ADC mode (elite = top10%)   5          1.00                 1.0
# 1  Novel/ADC mode (elite = top10%)  10          0.80                 1.0
# 2  Novel/ADC mode (elite = top10%)  20          0.85                 1.0
# 3  Novel/ADC mode (elite = top10%)  50          0.78                 0.9
# ==================== Biosimilar mode (elite = top2%) ====================
# Spearman(true_util vs pred_util): 0.7664165144165145
#                               mode   k  topk_overlap  elite_rate_in_topk
# 0  Biosimilar mode (elite = top2%)   5          0.60                1.00
# 1  Biosimilar mode (elite = top2%)  10          0.80                1.00
# 2  Biosimilar mode (elite = top2%)  20          0.75                0.75
# 3  Biosimilar mode (elite = top2%)  50          0.76                0.38
# ==================== Novel/ADC mode (elite = top2%) ====================
# Spearman(true_util vs pred_util): 0.8611812211812212
#                              mode   k  topk_overlap  elite_rate_in_topk
# 0  Novel/ADC mode (elite = top2%)   5          1.00                1.00
# 1  Novel/ADC mode (elite = top2%)  10          0.80                1.00
# 2  Novel/ADC mode (elite = top2%)  20          0.85                0.85
# 3  Novel/ADC mode (elite = top2%)  50          0.78                0.40
#                                 mode   k  topk_overlap  elite_rate_in_topk
# 0   Biosimilar mode (elite = top10%)   5          0.60                1.00
# 1   Biosimilar mode (elite = top10%)  10          0.80                1.00
# 2   Biosimilar mode (elite = top10%)  20          0.75                1.00
# 3   Biosimilar mode (elite = top10%)  50          0.76                0.88
# 4    Novel/ADC mode (elite = top10%)   5          1.00                1.00
# 5    Novel/ADC mode (elite = top10%)  10          0.80                1.00
# 6    Novel/ADC mode (elite = top10%)  20          0.85                1.00
# 7    Novel/ADC mode (elite = top10%)  50          0.78                0.90
# 8    Biosimilar mode (elite = top2%)   5          0.60                1.00
# 9    Biosimilar mode (elite = top2%)  10          0.80                1.00
# 10   Biosimilar mode (elite = top2%)  20          0.75                0.75
# 11   Biosimilar mode (elite = top2%)  50          0.76                0.38
# 12    Novel/ADC mode (elite = top2%)   5          1.00                1.00
# 13    Novel/ADC mode (elite = top2%)  10          0.80                1.00
# 14    Novel/ADC mode (elite = top2%)  20          0.85                0.85
# 15    Novel/ADC mode (elite = top2%)  50          0.78                0.40

# %% [markdown]
# ## D) Precision@K and NDCG@K (Top-10% and Top-5% elites)
#
# ### Why these metrics?
# - We care about **ranking** (Top-K decisions), not perfect numeric prediction.
# - R²/MAE can look poor even when Top-K ranking is useful.
#
# ### Definitions
# **Elite label**:
# - elite = top X% by **true utility** (offline evaluation)
#
# **Precision@K**:
# - Among the predicted Top-K clones (ranked by predicted utility),
#   what fraction are truly elite?
#
# **NDCG@K** (Normalized Discounted Cumulative Gain):
# - A ranking-quality score that rewards placing elite clones higher in the list.
# - It is more sensitive to the top of the ranking than Spearman.
#
# We compute these for:
# - Biosimilar mode utility (pred_util_bio vs elite_bio_*)
# - Novel/ADC mode utility (pred_util_novel vs elite_novel_*)
# - Elite thresholds: top 10% and top 5%
# - K = [5, 10, 20, 50]

# %%
K_LIST = [5, 10, 20, 50]

def precision_at_k(df: pd.DataFrame, score_col: str, elite_col: str, k: int) -> float:
    top = df.sort_values(score_col, ascending=False).head(k)
    return float(top[elite_col].mean())

def ndcg_at_k(df: pd.DataFrame, score_col: str, elite_col: str, k: int) -> float:
    """
    NDCG@K with binary relevance (elite=1 else 0).
    """
    top = df.sort_values(score_col, ascending=False).head(k)
    rel = top[elite_col].values.astype(float)

    # DCG: sum(rel_i / log2(i+2))
    discounts = 1.0 / np.log2(np.arange(2, len(rel) + 2))
    dcg = float(np.sum(rel * discounts))

    # IDCG: ideal DCG (sorted rel descending)
    ideal = np.sort(rel)[::-1]
    idcg = float(np.sum(ideal * discounts)) + 1e-12

    return dcg / idcg

def eval_prec_ndcg(df: pd.DataFrame, mode_name: str, score_col: str, elite_col: str):
    rows = []
    for k in K_LIST:
        rows.append({
            "mode": mode_name,
            "elite_def": elite_col,
            "k": k,
            "precision@k": precision_at_k(df, score_col, elite_col, k),
            "ndcg@k": ndcg_at_k(df, score_col, elite_col, k),
        })
    return pd.DataFrame(rows)

# We assume you already created these columns in earlier cells:
# - pred_util_bio, pred_util_novel
# - elite_bio_10, elite_bio_5
# - elite_novel_10, elite_novel_5
needed = ["pred_util_bio","pred_util_novel","elite_bio_10","elite_bio_5","elite_bio_2","elite_novel_10","elite_novel_5", "elite_novel_2"]
missing = [c for c in needed if c not in df_eval.columns]
if missing:
    raise ValueError(f"Missing columns in df_eval: {missing}. "
                     "Make sure you ran the Utility+Elite definition cells first.")

res = []
res.append(eval_prec_ndcg(df_eval, "biosimilar", "pred_util_bio", "elite_bio_10"))
res.append(eval_prec_ndcg(df_eval, "biosimilar", "pred_util_bio", "elite_bio_5"))
res.append(eval_prec_ndcg(df_eval, "biosimilar", "pred_util_bio", "elite_bio_2"))

res.append(eval_prec_ndcg(df_eval, "novel/ADC", "pred_util_novel", "elite_novel_10"))
res.append(eval_prec_ndcg(df_eval, "novel/ADC", "pred_util_novel", "elite_novel_5"))
res.append(eval_prec_ndcg(df_eval, "novel/ADC", "pred_util_novel", "elite_novel_2"))

prec_ndcg_table = pd.concat(res, ignore_index=True)
prec_ndcg_table
# Out:
#           mode       elite_def   k  precision@k    ndcg@k
# 0   biosimilar    elite_bio_10   5         1.00  1.000000
# 1   biosimilar    elite_bio_10  10         1.00  1.000000
# 2   biosimilar    elite_bio_10  20         1.00  1.000000
# 3   biosimilar    elite_bio_10  50         0.88  0.998668
# 4   biosimilar     elite_bio_5   5         1.00  1.000000
# 5   biosimilar     elite_bio_5  10         1.00  1.000000
# 6   biosimilar     elite_bio_5  20         1.00  1.000000
# 7   biosimilar     elite_bio_5  50         0.76  0.995058
# 8   biosimilar     elite_bio_2   5         1.00  1.000000
# 9   biosimilar     elite_bio_2  10         1.00  1.000000
# 10  biosimilar     elite_bio_2  20         0.75  0.996190
# 11  biosimilar     elite_bio_2  50         0.38  0.974119
# 12   novel/ADC  elite_novel_10   5         1.00  1.000000
# 13   novel/ADC  elite_novel_10  10         1.00  1.000000
# 14   novel/ADC  elite_novel_10  20         1.00  1.000000
# 15   novel/ADC  elite_novel_10  50         0.90  0.998496
# 16   novel/ADC   elite_novel_5   5         1.00  1.000000
# 17   novel/ADC   elite_novel_5  10         1.00  1.000000
# 18   novel/ADC   elite_novel_5  20         1.00  1.000000
# 19   novel/ADC   elite_novel_5  50         0.78  0.994928
# 20   novel/ADC   elite_novel_2   5         1.00  1.000000
# 21   novel/ADC   elite_novel_2  10         1.00  1.000000
# 22   novel/ADC   elite_novel_2  20         0.85  0.984693
# 23   novel/ADC   elite_novel_2  50         0.40  0.973122

# %%
# Optional: pivot for easier reading
pivot = prec_ndcg_table.pivot_table(
    index=["mode","elite_def","k"],
    values=["precision@k","ndcg@k"]
).reset_index()
pivot
# Out:
#           mode       elite_def   k    ndcg@k  precision@k
# 0   biosimilar    elite_bio_10   5  1.000000         1.00
# 1   biosimilar    elite_bio_10  10  1.000000         1.00
# 2   biosimilar    elite_bio_10  20  1.000000         1.00
# 3   biosimilar    elite_bio_10  50  0.998668         0.88
# 4   biosimilar     elite_bio_2   5  1.000000         1.00
# 5   biosimilar     elite_bio_2  10  1.000000         1.00
# 6   biosimilar     elite_bio_2  20  0.996190         0.75
# 7   biosimilar     elite_bio_2  50  0.974119         0.38
# 8   biosimilar     elite_bio_5   5  1.000000         1.00
# 9   biosimilar     elite_bio_5  10  1.000000         1.00
# 10  biosimilar     elite_bio_5  20  1.000000         1.00
# 11  biosimilar     elite_bio_5  50  0.995058         0.76
# 12   novel/ADC  elite_novel_10   5  1.000000         1.00
# 13   novel/ADC  elite_novel_10  10  1.000000         1.00
# 14   novel/ADC  elite_novel_10  20  1.000000         1.00
# 15   novel/ADC  elite_novel_10  50  0.998496         0.90
# 16   novel/ADC   elite_novel_2   5  1.000000         1.00
# 17   novel/ADC   elite_novel_2  10  1.000000         1.00
# 18   novel/ADC   elite_novel_2  20  0.984693         0.85
# 19   novel/ADC   elite_novel_2  50  0.973122         0.40
# 20   novel/ADC   elite_novel_5   5  1.000000         1.00
# 21   novel/ADC   elite_novel_5  10  1.000000         1.00
# 22   novel/ADC   elite_novel_5  20  1.000000         1.00
# 23   novel/ADC   elite_novel_5  50  0.994928         0.78

# %% [markdown]
# ## E) Utility Weight Sweep (Grid Search) — Find the best weights for Top-K selection
#
# ### Why do this?
# Our final CLD decision is multi-objective:
#
# - late productivity (titer): higher is better
# - stability drop: lower is better
# - quality risk (aggregation): lower is better
#
# But we do NOT know the best trade-off weights in advance.
# So we sweep (grid-search) weights and choose the best combination based on ranking metrics.
#
# ### What we optimize
# We evaluate predicted ranking quality vs true ranking quality using:
#
# - Precision@K (how many true-elite clones appear in predicted Top-K)
# - NDCG@K (ranking quality; rewards correct ordering near the top)
#
# We sweep weights for two business modes:
# 1) Biosimilar/commercial mode: prioritize titer + stability (agg lower weight)
# 2) Novel/ADC mode: prioritize quality (agg higher weight)
#
# This is an offline evaluation step (uses true late outcomes).
# In real CLD, we will apply the selected weights to predicted late outcomes only.

# %%
K_LIST = [5, 10, 20, 50]
ELITE_FRACS = [0.10, 0.05, 0.02]   # top 10%, 5%, 2%

def z(s):
    s = s.astype(float)
    return (s - s.mean()) / (s.std(ddof=0) + 1e-9)

def precision_at_k(df, score_col, elite_col, k):
    top = df.sort_values(score_col, ascending=False).head(k)
    return float(top[elite_col].mean())

def ndcg_at_k(df, score_col, elite_col, k):
    top = df.sort_values(score_col, ascending=False).head(k)
    rel = top[elite_col].values.astype(float)
    discounts = 1.0 / np.log2(np.arange(2, len(rel) + 2))
    dcg = float(np.sum(rel * discounts))
    ideal = np.sort(rel)[::-1]
    idcg = float(np.sum(ideal * discounts)) + 1e-12
    return dcg / idcg

def make_utility(df, prefix, w_titer, w_drop, w_agg):
    # utility = + titer - drop - agg (all z-scored)
    return (
        w_titer * z(df[f"{prefix}_late_titer"])
        - w_drop  * z(df[f"{prefix}_drop"])
        - w_agg   * z(df[f"{prefix}_late_agg"])
    )

def mark_elite(df, util_col, frac):
    thr = df[util_col].quantile(1 - frac)
    return (df[util_col] >= thr).astype(int)

# --- Required columns check ---
required = [
    "true_drop","pred_drop",
    "true_late_titer","pred_late_titer",
    "true_late_agg","pred_late_agg"
]
missing = [c for c in required if c not in df_eval.columns]
if missing:
    raise ValueError(f"Missing columns in df_eval: {missing}. "
                     "Make sure your prediction table contains true_* and pred_* columns.")

# --- Build a working copy ---
work = df_eval.copy()

# --- Weight grids ---
# Keep grids small first (fast); you can widen later.
# Biosimilar: agg weight small
grid_bio = {
    "w_titer": [0.5, 1.0, 1.5, 2.0],
    "w_drop":  [0.5, 1.0, 1.5, 2.0],
    "w_agg":   [0.0, 0.1, 0.2, 0.3],
}
# Novel/ADC: agg weight larger
grid_novel = {
    "w_titer": [0.5, 1.0, 1.5],
    "w_drop":  [0.5, 1.0, 1.5],
    "w_agg":   [0.5, 1.0, 1.5, 2.0],
}

def run_sweep(mode_name, grid):
    rows = []
    for wt in grid["w_titer"]:
        for wd in grid["w_drop"]:
            for wa in grid["w_agg"]:
                # define utilities
                work["true_util"] = make_utility(work, "true", wt, wd, wa)
                work["pred_util"] = make_utility(work, "pred", wt, wd, wa)

                # evaluate for each elite frac and each K
                for frac in ELITE_FRACS:
                    elite_col = f"elite_{int(frac*100)}"
                    work[elite_col] = mark_elite(work, "true_util", frac)

                    for k in K_LIST:
                        rows.append({
                            "mode": mode_name,
                            "w_titer": wt,
                            "w_drop": wd,
                            "w_agg": wa,
                            "elite_frac": frac,
                            "k": k,
                            "precision@k": precision_at_k(work, "pred_util", elite_col, k),
                            "ndcg@k": ndcg_at_k(work, "pred_util", elite_col, k),
                        })
    return pd.DataFrame(rows)

bio_sweep = run_sweep("biosimilar", grid_bio)
novel_sweep = run_sweep("novel/ADC", grid_novel)
sweep = pd.concat([bio_sweep, novel_sweep], ignore_index=True)

# --- Choose a primary objective for selection ---
# Example: maximize precision@20 at elite_frac=0.10 (top10%) and tie-break with ndcg@20
TARGET_FRAC = 0.10
TARGET_K = 20

subset = sweep[(sweep["elite_frac"] == TARGET_FRAC) & (sweep["k"] == TARGET_K)].copy()
subset = subset.sort_values(["precision@k","ndcg@k"], ascending=False)

print("Top candidates by Precision@20 (elite top10%), tie-break NDCG@20:")
subset.head(15)
# Out:
# Top candidates by Precision@20 (elite top10%), tie-break NDCG@20:
#            mode  w_titer  w_drop  w_agg  elite_frac   k  precision@k  ndcg@k
# 2    biosimilar      0.5     0.5    0.0         0.1  20          1.0     1.0
# 14   biosimilar      0.5     0.5    0.1         0.1  20          1.0     1.0
# 26   biosimilar      0.5     0.5    0.2         0.1  20          1.0     1.0
# 38   biosimilar      0.5     0.5    0.3         0.1  20          1.0     1.0
# 50   biosimilar      0.5     1.0    0.0         0.1  20          1.0     1.0
# 62   biosimilar      0.5     1.0    0.1         0.1  20          1.0     1.0
# 74   biosimilar      0.5     1.0    0.2         0.1  20          1.0     1.0
# 86   biosimilar      0.5     1.0    0.3         0.1  20          1.0     1.0
# 98   biosimilar      0.5     1.5    0.0         0.1  20          1.0     1.0
# 122  biosimilar      0.5     1.5    0.2         0.1  20          1.0     1.0
# 134  biosimilar      0.5     1.5    0.3         0.1  20          1.0     1.0
# 194  biosimilar      1.0     0.5    0.0         0.1  20          1.0     1.0
# 206  biosimilar      1.0     0.5    0.1         0.1  20          1.0     1.0
# 218  biosimilar      1.0     0.5    0.2         0.1  20          1.0     1.0
# 230  biosimilar      1.0     0.5    0.3         0.1  20          1.0     1.0

# %%
TARGET_FRAC = 0.02
TARGET_K = 20

subset_top2 = sweep[(sweep["elite_frac"] == TARGET_FRAC) & (sweep["k"] == TARGET_K)].copy()
subset_top2 = subset_top2.sort_values(["precision@k", "ndcg@k"], ascending=False)

print("Top candidates by Precision@20 (elite top2%), tie-break NDCG@20:")
subset_top2.head(15)
# Out:
# Top candidates by Precision@20 (elite top2%), tie-break NDCG@20:
#             mode  w_titer  w_drop  w_agg  elite_frac   k  precision@k  \
# 622   biosimilar      2.0     0.5    0.3        0.02  20         0.90
# 406   biosimilar      1.5     0.5    0.1        0.02  20         0.90
# 418   biosimilar      1.5     0.5    0.2        0.02  20         0.90
# 430   biosimilar      1.5     0.5    0.3        0.02  20         0.90
# 610   biosimilar      2.0     0.5    0.2        0.02  20         0.90
# 214   biosimilar      1.0     0.5    0.1        0.02  20         0.85
# 466   biosimilar      1.5     1.0    0.2        0.02  20         0.85
# 646   biosimilar      2.0     1.0    0.1        0.02  20         0.85
# 658   biosimilar      2.0     1.0    0.2        0.02  20         0.85
# 670   biosimilar      2.0     1.0    0.3        0.02  20         0.85
# 394   biosimilar      1.5     0.5    0.0        0.02  20         0.85
# 454   biosimilar      1.5     1.0    0.1        0.02  20         0.85
# 598   biosimilar      2.0     0.5    0.1        0.02  20         0.85
# 1078   novel/ADC      1.5     0.5    1.0        0.02  20         0.85
# 202   biosimilar      1.0     0.5    0.0        0.02  20         0.85
#
#         ndcg@k
# 622   1.000000
# 406   0.999388
# 418   0.999388
# 430   0.998718
# 610   0.998155
# 214   1.000000
# 466   1.000000
# 646   1.000000
# 658   1.000000
# 670   1.000000
# 394   0.999306
# 454   0.999306
# 598   0.998544
# 1078  0.997908
# 202   0.997701

# %%
subset[subset["mode"] == "biosimilar"].head(10)
# Out:
#            mode  w_titer  w_drop  w_agg  elite_frac   k  precision@k  ndcg@k
# 2    biosimilar      0.5     0.5    0.0         0.1  20          1.0     1.0
# 14   biosimilar      0.5     0.5    0.1         0.1  20          1.0     1.0
# 26   biosimilar      0.5     0.5    0.2         0.1  20          1.0     1.0
# 38   biosimilar      0.5     0.5    0.3         0.1  20          1.0     1.0
# 50   biosimilar      0.5     1.0    0.0         0.1  20          1.0     1.0
# 62   biosimilar      0.5     1.0    0.1         0.1  20          1.0     1.0
# 74   biosimilar      0.5     1.0    0.2         0.1  20          1.0     1.0
# 86   biosimilar      0.5     1.0    0.3         0.1  20          1.0     1.0
# 98   biosimilar      0.5     1.5    0.0         0.1  20          1.0     1.0
# 122  biosimilar      0.5     1.5    0.2         0.1  20          1.0     1.0

# %%
subset[subset["mode"] == "novel/ADC"].head(10)
# Out:
#           mode  w_titer  w_drop  w_agg  elite_frac   k  precision@k  ndcg@k
# 770  novel/ADC      0.5     0.5    0.5         0.1  20          1.0     1.0
# 782  novel/ADC      0.5     0.5    1.0         0.1  20          1.0     1.0
# 794  novel/ADC      0.5     0.5    1.5         0.1  20          1.0     1.0
# 806  novel/ADC      0.5     0.5    2.0         0.1  20          1.0     1.0
# 818  novel/ADC      0.5     1.0    0.5         0.1  20          1.0     1.0
# 830  novel/ADC      0.5     1.0    1.0         0.1  20          1.0     1.0
# 854  novel/ADC      0.5     1.0    2.0         0.1  20          1.0     1.0
# 866  novel/ADC      0.5     1.5    0.5         0.1  20          1.0     1.0
# 878  novel/ADC      0.5     1.5    1.0         0.1  20          1.0     1.0
# 890  novel/ADC      0.5     1.5    1.5         0.1  20          1.0     1.0

# %% [markdown]
# ## F) Heatmap of utility weight sweep
#
# To better understand how utility weights affect ranking quality, we visualize the sweep result as a heatmap.
#
# ### What this heatmap shows
# - x-axis: `w_titer`
# - y-axis: `w_drop`
# - cell value: `precision@k` or `ndcg@k`
# - `w_agg` is fixed for each heatmap panel
#
# This lets us see:
# - which combinations of productivity/stability weighting work best
# - whether biosimilar and novel/ADC modes prefer different utility regions
# - how sensitive the model is to the chosen objective function

# %%
# Choose what to inspect
TARGET_K = 20
TARGET_ELITE = 0.10   # top 10%
METRIC = "precision@k"   # or "ndcg@k"

def plot_weight_heatmaps(sweep_df, mode_name, metric="precision@k", elite_frac=0.10, k=20):
    sub = sweep_df[
        (sweep_df["mode"] == mode_name) &
        (sweep_df["elite_frac"] == elite_frac) &
        (sweep_df["k"] == k)
    ].copy()

    w_agg_values = sorted(sub["w_agg"].unique())

    n_panels = len(w_agg_values)
    fig, axes = plt.subplots(1, n_panels, figsize=(4 * n_panels, 4), squeeze=False)
    axes = axes[0]

    for ax, wagg in zip(axes, w_agg_values):
        tmp = sub[sub["w_agg"] == wagg].copy()

        pivot = tmp.pivot_table(
            index="w_drop",
            columns="w_titer",
            values=metric
        ).sort_index(ascending=False)

        im = ax.imshow(pivot.values, aspect="auto")
        ax.set_title(f"{mode_name}\n{metric}, elite={int(elite_frac*100)}%, K={k}\nw_agg={wagg}")
        ax.set_xticks(range(len(pivot.columns)))
        ax.set_xticklabels(pivot.columns)
        ax.set_yticks(range(len(pivot.index)))
        ax.set_yticklabels(pivot.index)
        ax.set_xlabel("w_titer")
        ax.set_ylabel("w_drop")

        # annotate cells
        for i in range(pivot.shape[0]):
            for j in range(pivot.shape[1]):
                val = pivot.values[i, j]
                ax.text(j, i, f"{val:.2f}", ha="center", va="center", fontsize=8)

        fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)

    plt.tight_layout()
    plt.show()

# %%
plot_weight_heatmaps(sweep, mode_name="biosimilar", metric="precision@k", elite_frac=0.10, k=20)
plot_weight_heatmaps(sweep, mode_name="novel/ADC", metric="precision@k", elite_frac=0.10, k=20)

# %%
plot_weight_heatmaps(sweep, mode_name="biosimilar", metric="ndcg@k", elite_frac=0.10, k=20)
plot_weight_heatmaps(sweep, mode_name="novel/ADC", metric="ndcg@k", elite_frac=0.10, k=20)

# %%
plot_weight_heatmaps(sweep, mode_name="biosimilar", metric="precision@k", elite_frac=0.02, k=20)
plot_weight_heatmaps(sweep, mode_name="novel/ADC", metric="precision@k", elite_frac=0.02, k=20)

plot_weight_heatmaps(sweep, mode_name="biosimilar", metric="ndcg@k", elite_frac=0.02, k=20)
plot_weight_heatmaps(sweep, mode_name="novel/ADC", metric="ndcg@k", elite_frac=0.02, k=20)

# %%
# Helper function to show feature importance for a model
# X_cols should be the list of feature names corresponding to model.feature_importances

def show_importance(model, X_cols, title, top_n=20):
    imp = pd.Series(model.feature_importances_, index=X_cols).sort_values(ascending=False)
    print(f"\n=== Feature importance: {title} (top {top_n}) ===")
    print(imp.head(top_n).to_string())
    return imp

# 1) Show feature importance for each model
imp_drop = show_importance(rf_drop, X.columns, "drop (stability)")
imp_titer = show_importance(rf_titer, X.columns, "late_titer")
imp_agg = show_importance(rf_agg, X.columns, "late_agg")

# 2) Check specific feature importance and rank for ddPCR copy number (ddpcr_cn)
FEATURE_CN = "ddpcr_cn"
print("\n=== ddPCR feature check ===")
print("ddpcr_cn in X.columns?", FEATURE_CN in X.columns)

if FEATURE_CN in X.columns:
    print("\nRank of ddpcr_cn:")
    print("drop model rank:", int(imp_drop.rank(ascending=False)[FEATURE_CN]))
    print("late_titer model rank:", int(imp_titer.rank(ascending=False)[FEATURE_CN]))
    print("late_agg model rank:", int(imp_agg.rank(ascending=False)[FEATURE_CN]))

    print("\nImportance value of ddpcr_cn:")
    print("drop model:", float(imp_drop[FEATURE_CN]))
    print("late_titer model:", float(imp_titer[FEATURE_CN]))
    print("late_agg model:", float(imp_agg[FEATURE_CN]))
else:
    print("ddpcr_cn feature not found. Make sure 02d merged ddPCR into X_v2 and 02c carried it into 3targets file.")
# Out:
# === Feature importance: drop (stability) (top 20) ===
# titer_slope         0.163833
# titer_cv            0.110754
# titer_std           0.108093
# titer_slope_7_10    0.057777
# titer_slope_3_6     0.041183
# vcd_slope           0.029172
# aggregation_std     0.027506
# qP_p10              0.026599
# titer_p10           0.024076
# vcd_p10             0.023002
# vcd_max             0.021803
# titer_min           0.021279
# titer_max           0.021136
# titer_curvature     0.020916
# titer_mean          0.020490
# qP_mean             0.018079
# vcd_mean            0.017244
# vcd_min             0.014782
# viability_mean      0.012916
# vcd_std             0.012198
#
# === Feature importance: late_titer (top 20) ===
# titer_p10           0.137215
# titer_min           0.128236
# qP_p10              0.116136
# titer_mean          0.080365
# vcd_max             0.067477
# qP_mean             0.064954
# vcd_mean            0.061241
# vcd_p10             0.059019
# titer_max           0.043568
# viability_mean      0.042738
# titer_cv            0.042294
# vcd_min             0.035865
# viability_max       0.023823
# viability_min       0.015893
# titer_slope         0.013972
# viability_p10       0.012715
# titer_std           0.011442
# vcd_cv              0.008143
# titer_slope_7_10    0.007397
# titer_slope_3_6     0.006085
#
# === Feature importance: late_agg (top 20) ===
# aggregation_mean          0.270706
# aggregation_min           0.226979
# aggregation_max           0.203021
# aggregation_p10           0.178177
# aggregation_cv            0.092524
# aggregation_std           0.003979
# ddpcr_cn                  0.001096
# aggregation_slope_7_10    0.001007
# aggregation_slope         0.000967
# titer_std                 0.000951
# vcd_cv                    0.000828
# aggregation_slope_3_6     0.000826
# titer_slope_7_10          0.000781
# titer_slope               0.000781
# aggregation_curvature     0.000745
# titer_slope_3_6           0.000735
# vcd_min                   0.000726
# viability_max             0.000724
# viability_mean            0.000722
# viability_slope           0.000709
#
# === ddPCR feature check ===
# ddpcr_cn in X.columns? True
#
# Rank of ddpcr_cn:
# drop model rank: 43
# late_titer model rank: 43
# late_agg model rank: 7
#
# Importance value of ddpcr_cn:
# drop model: 0.006532506094096662
# late_titer model: 0.00019227290575791074
# late_agg model: 0.0010958190954686628

# %%
related = [c for c in X.columns if ("titer" in c) or ("qP" in c) or ("ddpcr" in c)]
print("\nColumns related to productivity:", related[:30], "...")
# Out:
# Columns related to productivity: ['titer_mean', 'titer_std', 'titer_min', 'titer_max', 'titer_slope', 'titer_p10', 'titer_slope_3_6', 'titer_slope_7_10', 'titer_curvature', 'qP_mean', 'qP_p10', 'titer_cv', 'ddpcr_cn'] ...

# %%
import pandas as pd
from pathlib import Path

LATENT_PATH = Path(f"../data/synthetic/raw/clone_latent_truths_5000_{scenario}.csv")
lat = pd.read_csv(LATENT_PATH)

print("Loaded latent truth:", LATENT_PATH)
print(lat.columns.tolist())

lat.groupby("is_super")[["productivity","stability","k_decay_i"]].mean()
lat.groupby("is_aggressive")[["productivity","stability","k_decay_i"]].mean()
# Out:
# Loaded latent truth: ../data/synthetic/raw/clone_latent_truths_5000_legacy.csv
# ['clone_id', 'productivity', 'stability', 'quality_potential', 'G_platform', 'platform_group', 'CN_true', 'CN_obs', 'k_decay_i', 'is_super', 'is_aggressive']
#                productivity  stability  k_decay_i
# is_aggressive
# 0                 93.637113   0.619821   0.052506
# 1                160.399441   0.547986   0.058669

# %% [markdown]
# ## Sanity Check 1 — Feature leakage check
#
# We verify that the feature matrix `X` does NOT contain any direct late-stage labels or derived target columns.
#
# This is the most important check when performance suddenly becomes very high.
#
# Forbidden examples:
# - `late_mean_titer`
# - `late_mean_aggregation`
# - `productivity_drop_pct`
# - any `true_*`, `pred_*`, `utility`, `elite`, or subgroup target columns
#
# Expected result:
# - no forbidden columns found in `X`

# %%
# Sanity Check 1: leakage check in X
forbidden_exact = {
    "productivity_drop_pct",
    "late_mean_titer",
    "late_mean_aggregation",
    "true_drop",
    "pred_drop",
    "true_late_titer",
    "pred_late_titer",
    "true_late_agg",
    "pred_late_agg",
    "true_utility",
    "pred_utility",
    "true_util_bio",
    "pred_util_bio",
    "true_util_novel",
    "pred_util_novel",
    "is_super",
    "is_aggressive",
}

# loose pattern check too
forbidden_patterns = [
    "late_mean",
    "true_",
    "pred_",
    "utility",
    "elite_",
    "is_super",
    "is_aggressive",
]

exact_hits = [c for c in X.columns if c in forbidden_exact]
pattern_hits = [c for c in X.columns if any(p in c.lower() for p in forbidden_patterns)]

print("=== Leakage Check ===")
print("Exact forbidden hits:", exact_hits)
print("Pattern-based suspicious hits:", pattern_hits)

if exact_hits:
    raise ValueError(f"Leakage detected in X (exact forbidden columns): {exact_hits}")

# pattern hits may include harmless things; just inspect
print("Leakage check done.")
# Out:
# === Leakage Check ===
# Exact forbidden hits: []
# Pattern-based suspicious hits: []
# Leakage check done.

# %% [markdown]
# ## Sanity Check 2 — Permutation test
#
# We shuffle the training labels and retrain the model.
#
# If the current high performance is caused by leakage, the model may still look strong even after shuffling labels.
#
# Expected result:
# - permuted-label R² should be near 0 or negative
# - permuted-label Spearman should be near 0
#
# If permuted performance collapses, that supports that the model is using real signal rather than direct leakage.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from scipy.stats import spearmanr
import numpy as np
import pandas as pd

def fit_rf_reg(X_train, y_train):
    model = RandomForestRegressor(
        n_estimators=300,
        random_state=42,
        min_samples_leaf=5,
        max_features="sqrt"
    )
    model.fit(X_train, y_train)
    return model

rng = np.random.default_rng(42)

perm_results = []

targets_for_perm = [
    ("drop", y_drop_train, y_drop_test),
    ("late_titer", y_titer_train, y_titer_test),
    ("late_agg", y_agg_train, y_agg_test),
]

for name, y_train_true, y_test_true in targets_for_perm:
    y_train_perm = rng.permutation(y_train_true)

    model_perm = fit_rf_reg(X_train, y_train_perm)
    pred_perm = model_perm.predict(X_test)

    r2_perm = r2_score(y_test_true, pred_perm)
    sp_perm = spearmanr(y_test_true, pred_perm).correlation

    perm_results.append({
        "target": name,
        "perm_r2": float(r2_perm),
        "perm_spearman": float(sp_perm),
    })

perm_df = pd.DataFrame(perm_results)
perm_df
# Out:
#        target   perm_r2  perm_spearman
# 0        drop -0.017109      -0.021069
# 1  late_titer  0.021458       0.066362
# 2    late_agg -0.060611      -0.219354

# %% [markdown]
# ## Sanity Check 3 — Validation-only weight selection
#
# Previously, we selected utility weights using the same test set we later evaluated on.
# That can make the performance look better than it really is.
#
# So here we do a stricter check:
#
# 1. Split the current training set into:
#    - inner-train
#    - validation
#
# 2. Train regression models on inner-train only
#
# 3. Use validation set to choose the best utility weights
#
# 4. Evaluate the chosen weights on the untouched test set
#
# Expected result:
# - performance should decrease somewhat compared with test-tuned weights
# - but it should still remain clearly above random if the signal is real

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from scipy.stats import spearmanr
import numpy as np
import pandas as pd

# --- Helper functions ---
def z(s):
    s = pd.Series(s).astype(float)
    return (s - s.mean()) / (s.std(ddof=0) + 1e-9)

def precision_at_k_df(df, score_col, elite_col, k):
    top = df.sort_values(score_col, ascending=False).head(k)
    return float(top[elite_col].mean())

def ndcg_at_k_df(df, score_col, elite_col, k):
    top = df.sort_values(score_col, ascending=False).head(k)
    rel = top[elite_col].values.astype(float)
    discounts = 1.0 / np.log2(np.arange(2, len(rel) + 2))
    dcg = float(np.sum(rel * discounts))
    ideal = np.sort(rel)[::-1]
    idcg = float(np.sum(ideal * discounts)) + 1e-12
    return dcg / idcg

def make_util_from_cols(df, prefix, w_titer, w_drop, w_agg):
    return (
        w_titer * z(df[f"{prefix}_late_titer"])
        - w_drop * z(df[f"{prefix}_drop"])
        - w_agg * z(df[f"{prefix}_late_agg"])
    )

def fit_rf_reg_small(X_train, y_train):
    model = RandomForestRegressor(
        n_estimators=300,
        random_state=42,
        min_samples_leaf=5,
        max_features="sqrt"
    )
    model.fit(X_train, y_train)
    return model

# --- Split current train into inner-train and validation ---
inner_train_idx, val_idx = train_test_split(train_idx, test_size=0.25, random_state=123, shuffle=True)

X_inner = X.iloc[inner_train_idx].copy()
X_val   = X.iloc[val_idx].copy()
X_hold  = X.iloc[test_idx].copy()

# true labels
y_drop_inner  = y_drop.iloc[inner_train_idx].values
y_drop_val    = y_drop.iloc[val_idx].values
y_drop_hold   = y_drop.iloc[test_idx].values

y_titer_inner = y_titer.iloc[inner_train_idx].values
y_titer_val   = y_titer.iloc[val_idx].values
y_titer_hold  = y_titer.iloc[test_idx].values

y_agg_inner   = y_agg.iloc[inner_train_idx].values
y_agg_val     = y_agg.iloc[val_idx].values
y_agg_hold    = y_agg.iloc[test_idx].values

# --- Train on inner-train only ---
rf_drop_val  = fit_rf_reg_small(X_inner, y_drop_inner)
rf_titer_val = fit_rf_reg_small(X_inner, y_titer_inner)
rf_agg_val   = fit_rf_reg_small(X_inner, y_agg_inner)

# --- Build validation dataframe ---
val_df = pd.DataFrame({
    "true_drop": y_drop_val,
    "pred_drop": rf_drop_val.predict(X_val),
    "true_late_titer": y_titer_val,
    "pred_late_titer": rf_titer_val.predict(X_val),
    "true_late_agg": y_agg_val,
    "pred_late_agg": rf_agg_val.predict(X_val),
})

# --- Build holdout test dataframe ---
hold_df = pd.DataFrame({
    "true_drop": y_drop_hold,
    "pred_drop": rf_drop_val.predict(X_hold),
    "true_late_titer": y_titer_hold,
    "pred_late_titer": rf_titer_val.predict(X_hold),
    "true_late_agg": y_agg_hold,
    "pred_late_agg": rf_agg_val.predict(X_hold),
})

# --- Small sweep (fast sanity version) ---
grid_bio_small = {
    "w_titer": [0.5, 1.0, 1.5],
    "w_drop":  [0.5, 1.0, 1.5, 2.0],
    "w_agg":   [0.0, 0.1, 0.2],
}
grid_novel_small = {
    "w_titer": [0.5, 1.0],
    "w_drop":  [0.5, 1.0, 1.5],
    "w_agg":   [0.5, 1.0, 1.5],
}

TARGET_K = 20
ELITE_FRAC = 0.10

def sweep_best_on_validation(mode_name, grid, val_df):
    rows = []
    for wt in grid["w_titer"]:
        for wd in grid["w_drop"]:
            for wa in grid["w_agg"]:
                val_df = val_df.copy()
                val_df["true_util"] = make_util_from_cols(val_df, "true", wt, wd, wa)
                val_df["pred_util"] = make_util_from_cols(val_df, "pred", wt, wd, wa)

                thr = val_df["true_util"].quantile(1 - ELITE_FRAC)
                val_df["elite"] = (val_df["true_util"] >= thr).astype(int)

                rows.append({
                    "mode": mode_name,
                    "w_titer": wt,
                    "w_drop": wd,
                    "w_agg": wa,
                    "precision@20_val": precision_at_k_df(val_df, "pred_util", "elite", TARGET_K),
                    "ndcg@20_val": ndcg_at_k_df(val_df, "pred_util", "elite", TARGET_K),
                })

    out = pd.DataFrame(rows).sort_values(["precision@20_val", "ndcg@20_val"], ascending=False)
    return out

best_bio_val = sweep_best_on_validation("biosimilar", grid_bio_small, val_df).head(1)
best_novel_val = sweep_best_on_validation("novel/ADC", grid_novel_small, val_df).head(1)

display(best_bio_val)
display(best_novel_val)

# --- Evaluate chosen weights on untouched holdout test ---
def evaluate_chosen_weights(row, hold_df):
    wt, wd, wa = row["w_titer"], row["w_drop"], row["w_agg"]
    mode = row["mode"]

    tmp = hold_df.copy()
    tmp["true_util"] = make_util_from_cols(tmp, "true", wt, wd, wa)
    tmp["pred_util"] = make_util_from_cols(tmp, "pred", wt, wd, wa)

    thr = tmp["true_util"].quantile(1 - ELITE_FRAC)
    tmp["elite"] = (tmp["true_util"] >= thr).astype(int)

    return {
        "mode": mode,
        "w_titer": wt,
        "w_drop": wd,
        "w_agg": wa,
        "precision@20_test": precision_at_k_df(tmp, "pred_util", "elite", TARGET_K),
        "ndcg@20_test": ndcg_at_k_df(tmp, "pred_util", "elite", TARGET_K),
        "spearman_test": float(spearmanr(tmp["true_util"], tmp["pred_util"]).correlation),
    }

val_selected_results = pd.DataFrame([
    evaluate_chosen_weights(best_bio_val.iloc[0], hold_df),
    evaluate_chosen_weights(best_novel_val.iloc[0], hold_df),
])

val_selected_results
# Out:
#          mode  w_titer  w_drop  w_agg  precision@20_val  ndcg@20_val
# 0  biosimilar      0.5     0.5    0.0               1.0          1.0
#         mode  w_titer  w_drop  w_agg  precision@20_val  ndcg@20_val
# 0  novel/ADC      0.5     0.5    0.5               1.0          1.0
#          mode  w_titer  w_drop  w_agg  precision@20_test  ndcg@20_test  \
# 0  biosimilar      0.5     0.5    0.0                1.0           1.0
# 1   novel/ADC      0.5     0.5    0.5                1.0           1.0
#
#    spearman_test
# 0       0.760275
# 1       0.857824
