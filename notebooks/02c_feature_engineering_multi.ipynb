# %% [markdown]
# ### Goal
#
# In real CLD projects, late-stage outcomes (e.g. productivity, quality, stability)
# are *not available* at early decision time.
#
# However, for **model training and validation**, we need to construct *ground-truth*
# late-stage labels from historical (or simulated) data.
#
# In this notebook, we:
#
# - Load early-stage feature table (v2)
# - Compute late-stage outcomes directly from the raw SQLite DB
# - Attach those late labels to the early feature table
# - Save a **multi-target dataset** for downstream modeling
#
# This dataset will be used by:
# - Notebook 03b (multi-target ML models)
# - Notebook 04b (predicted-late-based clone selection)

# %%
import sqlite3
import pandas as pd
from pathlib import Path

scenario = "legacy" # 'legacy' or 'optimized'
n_clones = 5000

DB_PATH = f"../data/synthetic/raw/cld_{n_clones}clones_{scenario}.db"
FEATURE_PATH = f"../data/synthetic/processed/cld_features_with_label_v2_{n_clones}_{scenario}.csv"
OUT_PATH = f"../data/synthetic/processed/cld_features_with_labels_3targets_v2_24_30_{n_clones}_{scenario}.csv"

print("DB:", DB_PATH)
print("Feature input:", FEATURE_PATH)
print("Output:", OUT_PATH)
# Out:
# DB: ../data/synthetic/raw/cld_5000clones_legacy.db
# Feature input: ../data/synthetic/processed/cld_features_with_label_v2_5000_legacy.csv
# Output: ../data/synthetic/processed/cld_features_with_labels_3targets_v2_24_30_5000_legacy.csv

# %%
features = pd.read_csv(FEATURE_PATH)
features.head()
# Out:
#      clone_id  titer_mean  titer_std  titer_min  titer_max      vcd_mean  \
# 0  CLONE_0001    3.142136   0.219271   2.698838   3.439919  1.083374e+07
# 1  CLONE_0002    0.904944   0.109603   0.803284   1.141559  1.480237e+07
# 2  CLONE_0003    5.045860   0.382916   4.372261   5.533843  8.915354e+06
# 3  CLONE_0004    1.354368   0.364467   0.587097   1.712960  1.786686e+07
# 4  CLONE_0005    3.365629   0.253995   3.046187   3.803560  1.080455e+07
#
#         vcd_std       vcd_min       vcd_max  viability_mean  ...  \
# 0  5.675920e+05  1.013179e+07  1.192629e+07       94.797460  ...
# 1  1.073024e+06  1.360551e+07  1.648285e+07       95.662931  ...
# 2  6.404794e+05  7.768218e+06  9.791953e+06       93.506606  ...
# 3  1.164899e+06  1.629019e+07  1.948202e+07       98.886072  ...
# 4  1.224111e+06  9.122992e+06  1.251044e+07       94.013308  ...
#
#         qP_mean        qP_p10  titer_cv    vcd_cv  viability_cv  \
# 0  2.900326e-07  2.631328e-07  0.069784  0.052391      0.019119
# 1  6.113507e-08  7.474889e-08  0.121116  0.072490      0.012693
# 2  5.659741e-07  6.163784e-07  0.075887  0.071840      0.025316
# 3  7.580335e-08  3.013534e-08  0.269105  0.065199      0.011872
# 4  3.115010e-07  2.884335e-07  0.075467  0.113296      0.017274
#
#    aggregation_cv  culture_mode_fed-batch  culture_mode_perfusion  ddpcr_cn  \
# 0        0.026472                    True                   False       4.0
# 1        0.048463                    True                   False       2.0
# 2        0.109903                    True                   False       5.0
# 3        0.381364                   False                    True       4.0
# 4        0.066114                    True                   False       6.0
#
#    productivity_drop_pct
# 0               0.371476
# 1               0.218365
# 2               0.472004
# 3               0.832703
# 4               0.344950
#
# [5 rows x 47 columns]

# %%
print("Rows:", features.shape[0])
print("Columns:", features.shape[1])
# Out:
# Rows: 5000
# Columns: 47

# %%
def fetch_late_labels(conn, clone_list, late_start=24, late_end=30):
    """
    Compute late-stage mean titer and aggregation per clone.
    """
    if len(clone_list) == 0:
        return pd.DataFrame(
            columns=["clone_id", "late_mean_titer", "late_mean_aggregation"]
        )

    placeholders = ",".join(["?"] * len(clone_list))

    query = f"""
    SELECT
        p.clone_id,
        AVG(CASE WHEN ar.assay_type = 'titer' THEN ar.value END) AS late_mean_titer,
        AVG(CASE WHEN ar.assay_type = 'aggregation' THEN ar.value END) AS late_mean_aggregation
    FROM assay_result ar
    JOIN passage p ON p.passage_id = ar.passage_id
    WHERE p.passage_number BETWEEN ? AND ?
      AND p.clone_id IN ({placeholders})
    GROUP BY p.clone_id
    """

    params = [late_start, late_end] + list(clone_list)
    return pd.read_sql_query(query, conn, params=params)

# %%
conn = sqlite3.connect(DB_PATH)

late_labels = fetch_late_labels(
    conn,
    features["clone_id"].tolist(),
    late_start=24,
    late_end=30
)

conn.close()
late_labels.head()
# Out:
#      clone_id  late_mean_titer  late_mean_aggregation
# 0  CLONE_0001         2.064437               6.333889
# 1  CLONE_0002         0.704085               7.144205
# 2  CLONE_0003         2.759155               2.610875
# 3  CLONE_0004         0.241370               1.842977
# 4  CLONE_0005         2.230768               2.949963

# %%
dataset_3targets = features.merge(
    late_labels,
    on="clone_id",
    how="left"
)
dataset_3targets.head()
# Out:
#      clone_id  titer_mean  titer_std  titer_min  titer_max      vcd_mean  \
# 0  CLONE_0001    3.142136   0.219271   2.698838   3.439919  1.083374e+07
# 1  CLONE_0002    0.904944   0.109603   0.803284   1.141559  1.480237e+07
# 2  CLONE_0003    5.045860   0.382916   4.372261   5.533843  8.915354e+06
# 3  CLONE_0004    1.354368   0.364467   0.587097   1.712960  1.786686e+07
# 4  CLONE_0005    3.365629   0.253995   3.046187   3.803560  1.080455e+07
#
#         vcd_std       vcd_min       vcd_max  viability_mean  ...  titer_cv  \
# 0  5.675920e+05  1.013179e+07  1.192629e+07       94.797460  ...  0.069784
# 1  1.073024e+06  1.360551e+07  1.648285e+07       95.662931  ...  0.121116
# 2  6.404794e+05  7.768218e+06  9.791953e+06       93.506606  ...  0.075887
# 3  1.164899e+06  1.629019e+07  1.948202e+07       98.886072  ...  0.269105
# 4  1.224111e+06  9.122992e+06  1.251044e+07       94.013308  ...  0.075467
#
#      vcd_cv  viability_cv  aggregation_cv  culture_mode_fed-batch  \
# 0  0.052391      0.019119        0.026472                    True
# 1  0.072490      0.012693        0.048463                    True
# 2  0.071840      0.025316        0.109903                    True
# 3  0.065199      0.011872        0.381364                   False
# 4  0.113296      0.017274        0.066114                    True
#
#    culture_mode_perfusion  ddpcr_cn  productivity_drop_pct  late_mean_titer  \
# 0                   False       4.0               0.371476         2.064437
# 1                   False       2.0               0.218365         0.704085
# 2                   False       5.0               0.472004         2.759155
# 3                    True       4.0               0.832703         0.241370
# 4                   False       6.0               0.344950         2.230768
#
#    late_mean_aggregation
# 0               6.333889
# 1               7.144205
# 2               2.610875
# 3               1.842977
# 4               2.949963
#
# [5 rows x 49 columns]

# %%
dataset_3targets[
    ["productivity_drop_pct", "late_mean_titer", "late_mean_aggregation"]
].isna().mean()
# Out:
# productivity_drop_pct    0.0
# late_mean_titer          0.0
# late_mean_aggregation    0.0
# dtype: float64

# %%
out_dir = Path(OUT_PATH).parent
out_dir.mkdir(parents=True, exist_ok=True)

dataset_3targets.to_csv(OUT_PATH, index=False)
print("Saved:", OUT_PATH)
# Out:
# Saved: ../data/synthetic/processed/cld_features_with_labels_3targets_v2_24_30_5000_legacy.csv

# %% [markdown]
# ### Output
#
# We generated a **multi-target CLD dataset** with:
#
# - Early-stage features (v2)
# - Stability target: `productivity_drop_pct`
# - Productivity target: `late_mean_titer`
# - Quality target: `late_mean_aggregation`
#
# This dataset enables:
# - Multi-target regression (Notebook 03b)
# - Predicted-late decision simulation (Notebook 04b)
