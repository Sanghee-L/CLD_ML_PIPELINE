# %% [markdown]
# ### Goal
#
# In real CLD projects, late-stage outcomes (e.g. productivity, quality, stability)
# are *not available* at early decision time.
#
# However, for **model training and validation**, we need to construct *ground-truth*
# late-stage labels from historical (or simulated) data.
#
# In this notebook, we:
#
# - Load early-stage feature table (v2)
# - Compute late-stage outcomes directly from the raw SQLite DB
# - Attach those late labels to the early feature table
# - Save a **multi-target dataset** for downstream modeling
#
# This dataset will be used by:
# - Notebook 03b (multi-target ML models)
# - Notebook 04b (predicted-late-based clone selection)

# %%
import sqlite3
import pandas as pd
from pathlib import Path

# %%
# Paths
DB_PATH = "../data/synthetic/raw/cld_2000clones_optimized.db"  # or cld.db
FEATURE_PATH = "../data/synthetic/processed/cld_features_with_label_v2_optimized.csv"
OUT_PATH = "../data/synthetic/processed/cld_features_with_labels_3targets_v2_24_30_optimized.csv"

print("DB:", DB_PATH)
print("Feature input:", FEATURE_PATH)
print("Output:", OUT_PATH)
# Out:
# DB: ../data/synthetic/raw/cld_2000clones_optimized.db
# Feature input: ../data/synthetic/processed/cld_features_with_label_v2_optimized.csv
# Output: ../data/synthetic/processed/cld_features_with_labels_3targets_v2_24_30_optimized.csv

# %%
features = pd.read_csv(FEATURE_PATH)
features.head()
# Out:
#      clone_id  titer_mean  titer_std  titer_min  titer_max      vcd_mean  \
# 0  CLONE_0001    4.157159   0.192816   3.860974   4.438496  1.078353e+07
# 1  CLONE_0002    1.157587   0.153671   0.947550   1.357355  1.380078e+07
# 2  CLONE_0003    6.755881   0.284146   6.495962   7.333870  7.967046e+06
# 3  CLONE_0004    0.855995   0.195139   0.633887   1.111325  1.499608e+07
# 4  CLONE_0005    3.645849   0.184313   3.385108   3.961007  1.148447e+07
#
#         vcd_std       vcd_min       vcd_max  viability_mean  ...  \
# 0  9.528191e+05  9.237027e+06  1.225314e+07       94.610357  ...
# 1  7.759186e+05  1.280831e+07  1.546131e+07       96.016350  ...
# 2  8.931379e+05  6.594390e+06  8.969199e+06       94.214253  ...
# 3  6.463732e+05  1.402751e+07  1.576869e+07       97.265204  ...
# 4  1.037870e+06  9.182657e+06  1.233431e+07       95.017839  ...
#
#         qP_mean        qP_p10  titer_cv    vcd_cv  viability_cv  \
# 0  3.855100e-07  3.678660e-07  0.046382  0.088359      0.014066
# 1  8.387832e-08  7.087946e-08  0.132751  0.056223      0.015984
# 2  8.479782e-07  7.661017e-07  0.042059  0.112104      0.019644
# 3  5.708124e-08  4.048689e-08  0.227968  0.043103      0.013718
# 4  3.174591e-07  3.114189e-07  0.050554  0.090372      0.018610
#
#    aggregation_cv  culture_mode_fed-batch  culture_mode_perfusion  ddpcr_cn  \
# 0        0.044074                    True                   False       3.0
# 1        0.131968                   False                    True       2.0
# 2        0.031644                    True                   False       4.0
# 3        0.036033                   False                    True       3.0
# 4        0.244859                    True                   False       4.0
#
#    productivity_drop_pct
# 0               0.178020
# 1               0.173411
# 2               0.207761
# 3               0.230650
# 4               0.300369
#
# [5 rows x 47 columns]

# %%
print("Rows:", features.shape[0])
print("Columns:", features.shape[1])
# Out:
# Rows: 2000
# Columns: 47

# %%
def fetch_late_labels(conn, clone_list, late_start=24, late_end=30):
    """
    Compute late-stage mean titer and aggregation per clone.
    """
    if len(clone_list) == 0:
        return pd.DataFrame(
            columns=["clone_id", "late_mean_titer", "late_mean_aggregation"]
        )

    placeholders = ",".join(["?"] * len(clone_list))

    query = f"""
    SELECT
        p.clone_id,
        AVG(CASE WHEN ar.assay_type = 'titer' THEN ar.value END) AS late_mean_titer,
        AVG(CASE WHEN ar.assay_type = 'aggregation' THEN ar.value END) AS late_mean_aggregation
    FROM assay_result ar
    JOIN passage p ON p.passage_id = ar.passage_id
    WHERE p.passage_number BETWEEN ? AND ?
      AND p.clone_id IN ({placeholders})
    GROUP BY p.clone_id
    """

    params = [late_start, late_end] + list(clone_list)
    return pd.read_sql_query(query, conn, params=params)

# %%
conn = sqlite3.connect(DB_PATH)

late_labels = fetch_late_labels(
    conn,
    features["clone_id"].tolist(),
    late_start=24,
    late_end=30
)

conn.close()
late_labels.head()
# Out:
#      clone_id  late_mean_titer  late_mean_aggregation
# 0  CLONE_0001         3.435080               3.956454
# 1  CLONE_0002         0.964185               3.034713
# 2  CLONE_0003         5.479359               5.807651
# 3  CLONE_0004         0.722980               7.254521
# 4  CLONE_0005         2.608790               1.081823

# %%
dataset_3targets = features.merge(
    late_labels,
    on="clone_id",
    how="left"
)
dataset_3targets.head()
# Out:
#      clone_id  titer_mean  titer_std  titer_min  titer_max      vcd_mean  \
# 0  CLONE_0001    4.157159   0.192816   3.860974   4.438496  1.078353e+07
# 1  CLONE_0002    1.157587   0.153671   0.947550   1.357355  1.380078e+07
# 2  CLONE_0003    6.755881   0.284146   6.495962   7.333870  7.967046e+06
# 3  CLONE_0004    0.855995   0.195139   0.633887   1.111325  1.499608e+07
# 4  CLONE_0005    3.645849   0.184313   3.385108   3.961007  1.148447e+07
#
#         vcd_std       vcd_min       vcd_max  viability_mean  ...  titer_cv  \
# 0  9.528191e+05  9.237027e+06  1.225314e+07       94.610357  ...  0.046382
# 1  7.759186e+05  1.280831e+07  1.546131e+07       96.016350  ...  0.132751
# 2  8.931379e+05  6.594390e+06  8.969199e+06       94.214253  ...  0.042059
# 3  6.463732e+05  1.402751e+07  1.576869e+07       97.265204  ...  0.227968
# 4  1.037870e+06  9.182657e+06  1.233431e+07       95.017839  ...  0.050554
#
#      vcd_cv  viability_cv  aggregation_cv  culture_mode_fed-batch  \
# 0  0.088359      0.014066        0.044074                    True
# 1  0.056223      0.015984        0.131968                   False
# 2  0.112104      0.019644        0.031644                    True
# 3  0.043103      0.013718        0.036033                   False
# 4  0.090372      0.018610        0.244859                    True
#
#    culture_mode_perfusion  ddpcr_cn  productivity_drop_pct  late_mean_titer  \
# 0                   False       3.0               0.178020         3.435080
# 1                    True       2.0               0.173411         0.964185
# 2                   False       4.0               0.207761         5.479359
# 3                    True       3.0               0.230650         0.722980
# 4                   False       4.0               0.300369         2.608790
#
#    late_mean_aggregation
# 0               3.956454
# 1               3.034713
# 2               5.807651
# 3               7.254521
# 4               1.081823
#
# [5 rows x 49 columns]

# %%
dataset_3targets[
    ["productivity_drop_pct", "late_mean_titer", "late_mean_aggregation"]
].isna().mean()
# Out:
# productivity_drop_pct    0.0
# late_mean_titer          0.0
# late_mean_aggregation    0.0
# dtype: float64

# %%
out_dir = Path(OUT_PATH).parent
out_dir.mkdir(parents=True, exist_ok=True)

dataset_3targets.to_csv(OUT_PATH, index=False)
print("Saved:", OUT_PATH)
# Out:
# Saved: ../data/synthetic/processed/cld_features_with_labels_3targets_v2_24_30_optimized.csv

# %% [markdown]
# ### Output
#
# We generated a **multi-target CLD dataset** with:
#
# - Early-stage features (v2)
# - Stability target: `productivity_drop_pct`
# - Productivity target: `late_mean_titer`
# - Quality target: `late_mean_aggregation`
#
# This dataset enables:
# - Multi-target regression (Notebook 03b)
# - Predicted-late decision simulation (Notebook 04b)
