# %% [markdown]
# # Notebook 02 — Feature Engineering and Target Construction for CLD Modeling
#
# ## Goal
#
# This notebook builds the canonical clone-level dataset used for downstream machine learning.
#
# It performs two linked tasks:
#
# ### 1. Feature engineering
# Transform raw early-stage assay measurements into clone-level model inputs.
#
# - **Feature engineering** means converting raw measurements into variables that a model can use.
# - Examples:
#   - mean
#   - standard deviation
#   - slope
#   - last observed value
#   - qP proxy
#
# ### 2. Target construction
# Compute late-stage clone outcomes from the raw database.
#
# - **Target construction** means defining the values the model should predict.
# - In this project, the main targets are:
#   - late qP
#   - qP drop
#   - stability label
#   - late aggregation
#
# ---
#
# ## Important principle: leakage-safe design
#
# This notebook uses only **early-stage information** to build features.
#
# - **Leakage** (or **target leakage**) means future information accidentally enters the feature set.
# - That would make model performance look unrealistically good.
#
# So the workflow is:
#
# - early passages → features
# - late passages → targets only
#
# ---
#
# ## Important term: qP proxy
#
# In this notebook, productivity is represented using a **qP proxy**:
#
# - `qP_proxy = titer / VCD`
#
# This should be interpreted as a **relative productivity measure**
# for clone comparison, not as a fully calibrated physical qP unit.
#
# ---
#
# ## Output
#
# This notebook saves:
#
# 1. **features-only table**
# 2. **canonical modeling dataset**
#
# The final dataset is used by:
#
# - Notebook 03b — prediction engine
# - Notebook 04b — decision engine

# %%
import sqlite3
import numpy as np
import pandas as pd
from pathlib import Path

scenario = "legacy"   # or "optimized"
n_clones = 5000

EARLY_START = 3
EARLY_END = 10
LATE_START = 24
LATE_END = 30
STABILITY_DROP_THRESHOLD = 0.30

DB_PATH = Path(f"../data/synthetic/raw/cld_{n_clones}clones_{scenario}.db")
OUT_DIR = Path("../data/synthetic/processed")

OUT_FEATURES = OUT_DIR / f"cld_features_v2_{n_clones}_{scenario}.csv"
OUT_DATASET = OUT_DIR / (
    f"cld_features_with_labels_qp_targets_v2_{LATE_START}_{LATE_END}_{n_clones}_{scenario}.csv"
)

print("DB:", DB_PATH)
print("Output features:", OUT_FEATURES)
print("Output dataset:", OUT_DATASET)
print("Early window:", EARLY_START, EARLY_END)
print("Late window:", LATE_START, LATE_END)
print("Stable threshold:", STABILITY_DROP_THRESHOLD)

# %% [markdown]
# ## 1. Load raw assay data
#
# We load assay-level data directly from the SQLite database.
#
# This raw data will be used to build:
#
# - early-stage features
# - late-stage targets
#
# Only early passages will be used for feature engineering.
# Late passages will only be used for target construction.

# %%
conn = sqlite3.connect(DB_PATH)

assay = pd.read_sql_query("""
SELECT
    ar.assay_id,
    ar.assay_type,
    ar.value,
    ar.unit,
    ar.method,
    ar.batch_id,
    p.clone_id,
    p.passage_number,
    p.phase
FROM assay_result ar
JOIN passage p
  ON p.passage_id = ar.passage_id
""", conn)

print("Assay rows:", len(assay))
display(assay.head())

# %%
def fetch_late_labels(conn, clone_list, late_start=24, late_end=30):
    """
    Compute late-stage mean qP and aggregation per clone.

    qP proxy is computed passage-wise as:
        qP = titer / vcd
    and then averaged over the late window.
    """
    if len(clone_list) == 0:
        return pd.DataFrame(
            columns=[
                "clone_id",
                "late_mean_titer",
                "late_mean_vcd",
                "late_mean_qp",
                "late_mean_aggregation",
            ]
        )

    placeholders = ",".join(["?"] * len(clone_list))

    query = f"""
    WITH late_assays AS (
        SELECT
            p.clone_id,
            p.passage_number,
            AVG(CASE WHEN ar.assay_type = 'titer' THEN ar.value END) AS titer_value,
            AVG(CASE WHEN ar.assay_type = 'vcd' THEN ar.value END) AS vcd_value,
            AVG(CASE WHEN ar.assay_type = 'aggregation' THEN ar.value END) AS aggregation_value
        FROM assay_result ar
        JOIN passage p
          ON p.passage_id = ar.passage_id
        WHERE p.passage_number BETWEEN ? AND ?
          AND p.clone_id IN ({placeholders})
        GROUP BY p.clone_id, p.passage_number
    )
    SELECT
        clone_id,
        AVG(titer_value) AS late_mean_titer,
        AVG(vcd_value) AS late_mean_vcd,
        AVG(titer_value / NULLIF(vcd_value, 0)) AS late_mean_qp,
        AVG(aggregation_value) AS late_mean_aggregation
    FROM late_assays
    GROUP BY clone_id
    """

    params = [late_start, late_end] + list(clone_list)
    return pd.read_sql_query(query, conn, params=params)

# %%
conn = sqlite3.connect(DB_PATH)

late_labels = fetch_late_labels(
    conn,
    features["clone_id"].tolist(),
    late_start=LATE_START,
    late_end=LATE_END
)

conn.close()
late_labels.head()
# Out:
#      clone_id  late_mean_titer  late_mean_vcd  late_mean_qp  \
# 0  CLONE_0001         2.060786   1.447989e+07  1.422965e-07
# 1  CLONE_0002         0.534174   1.630527e+07  3.273106e-08
# 2  CLONE_0003         2.812758   1.299184e+07  2.179665e-07
# 3  CLONE_0004         0.264075   1.729422e+07  1.530759e-08
# 4  CLONE_0005         2.237480   1.415976e+07  1.582179e-07
#
#    late_mean_aggregation
# 0               7.343369
# 1               6.090907
# 2               0.954037
# 3               3.358866
# 4               3.433430

# %%
dataset_targets = features.merge(
    late_labels,
    on="clone_id",
    how="left"
)

# --------------------------------------------------
# qP-based productivity / stability targets
# --------------------------------------------------
# early productivity target = early mean qP from 02d
# late productivity target = late mean qP from raw DB
dataset_targets["early_mean_qp"] = dataset_targets["qP_mean"]

# stability = relative qP drop
eps = 1e-12
dataset_targets["qp_drop_pct"] = (
    (dataset_targets["early_mean_qp"] - dataset_targets["late_mean_qp"])
    / (dataset_targets["early_mean_qp"] + eps)
)

# keep in sensible range for synthetic edge cases
dataset_targets["qp_drop_pct"] = dataset_targets["qp_drop_pct"].clip(lower=0.0, upper=1.5)

# binary stable label: drop <= 30%
dataset_targets["stable_label_30pct"] = (
    dataset_targets["qp_drop_pct"] <= STABILITY_DROP_THRESHOLD
).astype(int)

dataset_targets.head()
# Out:
#      clone_id  titer_mean  titer_std  titer_min  titer_max      vcd_mean  \
# 0  CLONE_0001    3.329594   0.231718   3.038644   3.677143  1.116369e+07
# 1  CLONE_0002    0.860239   0.198256   0.587189   1.167360  1.452452e+07
# 2  CLONE_0003    5.125209   0.377800   4.650505   5.589253  8.562655e+06
# 3  CLONE_0004    1.465522   0.354536   0.904352   1.933659  1.768095e+07
# 4  CLONE_0005    3.413942   0.173701   3.190777   3.635576  1.146771e+07
#
#          vcd_std       vcd_min       vcd_max  viability_mean  ...  \
# 0  632529.287976  1.011644e+07  1.178753e+07       93.854453  ...
# 1  554346.369067  1.349679e+07  1.546015e+07       96.626236  ...
# 2  902165.767440  6.976514e+06  9.908015e+06       93.941251  ...
# 3  655716.212327  1.663164e+07  1.843771e+07       98.937334  ...
# 4  823969.127959  1.019319e+07  1.278415e+07       94.393501  ...
#
#    culture_mode_perfusion  ddpcr_cn  productivity_drop_pct  late_mean_titer  \
# 0                   False       4.0               0.388597         2.060786
# 1                   False       2.0               0.477870         0.534174
# 2                   False       5.0               0.455607         2.812758
# 3                   False       4.0               0.826609         0.264075
# 4                    True       6.0               0.332801         2.237480
#
#    late_mean_vcd  late_mean_qp  late_mean_aggregation  early_mean_qp  \
# 0   1.447989e+07  1.422965e-07               7.343369   2.982521e-07
# 1   1.630527e+07  3.273106e-08               6.090907   5.922666e-08
# 2   1.299184e+07  2.179665e-07               0.954037   5.985538e-07
# 3   1.729422e+07  1.530759e-08               3.358866   8.288706e-08
# 4   1.415976e+07  1.582179e-07               3.433430   2.977006e-07
#
#    qp_drop_pct  stable_label_30pct
# 0     0.522897                   0
# 1     0.447352                   0
# 2     0.635844                   0
# 3     0.815310                   0
# 4     0.468532                   0
#
# [5 rows x 54 columns]

# %%
dataset_targets[
    [
        "early_mean_qp",
        "late_mean_qp",
        "qp_drop_pct",
        "stable_label_30pct",
        "late_mean_aggregation",
    ]
].isna().mean()
# Out:
# early_mean_qp            0.0
# late_mean_qp             0.0
# qp_drop_pct              0.0
# stable_label_30pct       0.0
# late_mean_aggregation    0.0
# dtype: float64

# %%
dataset_targets[
    [
        "early_mean_qp",
        "late_mean_qp",
        "qp_drop_pct",
        "stable_label_30pct",
        "late_mean_aggregation",
    ]
].describe()
# Out:
#        early_mean_qp  late_mean_qp  qp_drop_pct  stable_label_30pct  \
# count   5.000000e+03  5.000000e+03  5000.000000         5000.000000
# mean    3.394786e-07  1.898080e-07     0.445965            0.179800
# std     2.635303e-06  2.390419e-06     0.162457            0.384059
# min     8.917763e-09  1.376023e-09     0.000000            0.000000
# 25%     8.190160e-08  4.294516e-08     0.331633            0.000000
# 50%     1.464651e-07  7.898674e-08     0.430262            0.000000
# 75%     2.686983e-07  1.472280e-07     0.540189            0.000000
# max     1.658928e-04  1.655993e-04     0.990374            1.000000
#
#        late_mean_aggregation
# count            5000.000000
# mean                6.349806
# std                 3.193522
# min                 0.000000
# 25%                 3.911328
# 50%                 6.137498
# 75%                 8.537654
# max                18.098334

# %%
# --------------------------------------------------
# Remove legacy late-stage columns before saving
# --------------------------------------------------
# We keep qP-based targets for downstream notebooks (03b / 04b),
# and remove old late-stage summary columns that can cause leakage
# or schema confusion.

legacy_cols_to_remove = [
    "late_mean_titer",
    "late_mean_vcd",
    "productivity_drop_pct",   # remove if it exists from older versions
]

existing_legacy = [c for c in legacy_cols_to_remove if c in dataset_targets.columns]
print("Removing legacy columns before save:", existing_legacy)

dataset_targets = dataset_targets.drop(columns=existing_legacy, errors="ignore").copy()

print("\nSchema check after cleanup:")
for c in [
    "early_mean_qp",
    "late_mean_qp",
    "qp_drop_pct",
    "stable_label_30pct",
    "late_mean_aggregation",
    "late_mean_titer",
    "late_mean_vcd",
    "productivity_drop_pct",
]:
    print(f"{c}: {c in dataset_targets.columns}")
# Out:
# Removing legacy columns before save: ['late_mean_titer', 'late_mean_vcd', 'productivity_drop_pct']
#
# Schema check after cleanup:
# early_mean_qp: True
# late_mean_qp: True
# qp_drop_pct: True
# stable_label_30pct: True
# late_mean_aggregation: True
# late_mean_titer: False
# late_mean_vcd: False
# productivity_drop_pct: False

# %%
out_dir = Path(OUT_PATH).parent
out_dir.mkdir(parents=True, exist_ok=True)

dataset_targets.to_csv(OUT_PATH, index=False)
print("Saved:", OUT_PATH)
# Out:
# Saved: ../data/synthetic/processed/cld_features_with_labels_qp_targets_v2_24_30_5000_legacy.csv

# %%
saved_df = pd.read_csv(OUT_PATH)

print("Saved shape:", saved_df.shape)
print("\nSaved columns check:")

for c in [
    "early_mean_qp",
    "late_mean_qp",
    "qp_drop_pct",
    "stable_label_30pct",
    "late_mean_aggregation",
    "late_mean_titer",
    "late_mean_vcd",
    "productivity_drop_pct",
]:
    print(f"{c}: {c in saved_df.columns}")
# Out:
# Saved shape: (5000, 51)
#
# Saved columns check:
# early_mean_qp: True
# late_mean_qp: True
# qp_drop_pct: True
# stable_label_30pct: True
# late_mean_aggregation: True
# late_mean_titer: False
# late_mean_vcd: False
# productivity_drop_pct: False

# %% [markdown]
# ## Generated CLD Dataset (Multi-target)
#
# This notebook generated a multi-target dataset for clone selection modeling.
#
# ### 🔹 Features
# - Early-stage features (v2)
#   - productivity (qP)
#   - growth rate (μ)
#   - viability
#   - VCD
#
# ### 🎯 Targets
#
# **1. Productivity**
# - `late_mean_qp`
# - Average qP over late passage window (e.g., P24–30)
#
# **2. Stability**
# - `qp_drop_pct`
#   - Relative drop from early to late productivity
# - `stable_label_30pct`
#   - Stable if drop ≤ 30%
#   - Unstable if drop > 30%
#
# **3. Quality (temporary)**
# - `late_mean_aggregation`
# - Note: Glycan CQAs will be added in future versions
#
# ---
# Legacy late-stage summary columns such as `late_mean_titer` and `late_mean_vcd`
# are removed before saving, so downstream notebooks use only the qP-based target schema.
#
# ---
#
# ### Downstream Usage
#
# This dataset will be used in:
#
# - **Notebook 03b**
#   - Multi-target machine learning models
#
# - **Notebook 04b**
#   - Clone selection pipeline based on predicted late-stage performance

# %%
print(dataset_targets.shape)

print(
    dataset_targets[
        ["early_mean_qp", "late_mean_qp", "qp_drop_pct", "stable_label_30pct", "late_mean_aggregation"]
    ].head()
)

print(
    dataset_targets[
        ["qp_drop_pct", "stable_label_30pct", "late_mean_qp", "late_mean_aggregation"]
    ].describe()
)
# Out:
# (5000, 51)
#    early_mean_qp  late_mean_qp  qp_drop_pct  stable_label_30pct  \
# 0   2.982521e-07  1.422965e-07     0.522897                   0
# 1   5.922666e-08  3.273106e-08     0.447352                   0
# 2   5.985538e-07  2.179665e-07     0.635844                   0
# 3   8.288706e-08  1.530759e-08     0.815310                   0
# 4   2.977006e-07  1.582179e-07     0.468532                   0
#
#    late_mean_aggregation
# 0               7.343369
# 1               6.090907
# 2               0.954037
# 3               3.358866
# 4               3.433430
#        qp_drop_pct  stable_label_30pct  late_mean_qp  late_mean_aggregation
# count  5000.000000         5000.000000  5.000000e+03            5000.000000
# mean      0.445965            0.179800  1.898080e-07               6.349806
# std       0.162457            0.384059  2.390419e-06               3.193522
# min       0.000000            0.000000  1.376023e-09               0.000000
# 25%       0.331633            0.000000  4.294516e-08               3.911328
# 50%       0.430262            0.000000  7.898674e-08               6.137498
# 75%       0.540189            0.000000  1.472280e-07               8.537654
# max       0.990374            1.000000  1.655993e-04              18.098334
