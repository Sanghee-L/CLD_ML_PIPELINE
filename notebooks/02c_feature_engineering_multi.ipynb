# %% [markdown]
# ### Goal
#
# In real CLD projects, late-stage outcomes (e.g. productivity, quality, stability)
# are *not available* at early decision time.
#
# However, for **model training and validation**, we need to construct *ground-truth*
# late-stage labels from historical (or simulated) data.
#
# In this notebook, we:
#
# - Load early-stage feature table (v2)
# - Compute late-stage outcomes directly from the raw SQLite DB
# - Attach those late labels to the early feature table
# - Save a **multi-target dataset** for downstream modeling
#
# This dataset will be used by:
# - Notebook 03b (multi-target ML models)
# - Notebook 04b (predicted-late-based clone selection)

# %%
import sqlite3
import pandas as pd
from pathlib import Path

scenario = "optimized" # 'legacy' or 'optimized'
n_clones = 5000

DB_PATH = f"../data/synthetic/raw/cld_{n_clones}clones_{scenario}.db"
FEATURE_PATH = f"../data/synthetic/processed/cld_features_with_label_v2_{n_clones}_{scenario}.csv"
OUT_PATH = f"../data/synthetic/processed/cld_features_with_labels_3targets_v2_24_30_{n_clones}_{scenario}.csv"

print("DB:", DB_PATH)
print("Feature input:", FEATURE_PATH)
print("Output:", OUT_PATH)
# Out:
# DB: ../data/synthetic/raw/cld_5000clones_optimized.db
# Feature input: ../data/synthetic/processed/cld_features_with_label_v2_5000_optimized.csv
# Output: ../data/synthetic/processed/cld_features_with_labels_3targets_v2_24_30_5000_optimized.csv

# %%
features = pd.read_csv(FEATURE_PATH)
features.head()
# Out:
#      clone_id  titer_mean  titer_std  titer_min  titer_max      vcd_mean  \
# 0  CLONE_0001    4.290966   0.237332   3.898584   4.553147  1.016940e+07
# 1  CLONE_0002    1.134655   0.258193   0.714161   1.444387  1.441390e+07
# 2  CLONE_0003    6.639008   0.255518   6.154533   6.981924  8.031025e+06
# 3  CLONE_0004    1.017127   0.098740   0.919394   1.192629  1.503736e+07
# 4  CLONE_0005    3.844215   0.100473   3.696327   3.970858  1.115742e+07
#
#         vcd_std       vcd_min       vcd_max  viability_mean  ...  \
# 0  1.094181e+06  9.037823e+06  1.218882e+07       94.660676  ...
# 1  5.821027e+05  1.342995e+07  1.518339e+07       96.027597  ...
# 2  9.000477e+05  6.624924e+06  8.915702e+06       93.638460  ...
# 3  6.149093e+05  1.394330e+07  1.602700e+07       95.656109  ...
# 4  6.590394e+05  1.039616e+07  1.237306e+07       94.434050  ...
#
#         qP_mean        qP_p10  titer_cv    vcd_cv  viability_cv  \
# 0  4.219487e-07  4.194526e-07  0.055310  0.107595      0.010232
# 1  7.871955e-08  8.697385e-08  0.227552  0.040385      0.019042
# 2  8.266700e-07  8.156679e-07  0.038487  0.112071      0.015079
# 3  6.763999e-08  6.705722e-08  0.097078  0.040892      0.017374
# 4  3.445434e-07  3.622621e-07  0.026136  0.059067      0.016246
#
#    aggregation_cv  culture_mode_fed-batch  culture_mode_perfusion  ddpcr_cn  \
# 0        0.058636                    True                   False       4.0
# 1        0.042814                   False                    True       2.0
# 2        0.325755                    True                   False       4.0
# 3        0.371007                    True                   False       3.0
# 4        0.090028                    True                   False       4.0
#
#    productivity_drop_pct
# 0               0.087531
# 1              -0.097540
# 2               0.230329
# 3               0.184845
# 4               0.070410
#
# [5 rows x 47 columns]

# %%
print("Rows:", features.shape[0])
print("Columns:", features.shape[1])
# Out:
# Rows: 5000
# Columns: 47

# %%
def fetch_late_labels(conn, clone_list, late_start=24, late_end=30):
    """
    Compute late-stage mean titer and aggregation per clone.
    """
    if len(clone_list) == 0:
        return pd.DataFrame(
            columns=["clone_id", "late_mean_titer", "late_mean_aggregation"]
        )

    placeholders = ",".join(["?"] * len(clone_list))

    query = f"""
    SELECT
        p.clone_id,
        AVG(CASE WHEN ar.assay_type = 'titer' THEN ar.value END) AS late_mean_titer,
        AVG(CASE WHEN ar.assay_type = 'aggregation' THEN ar.value END) AS late_mean_aggregation
    FROM assay_result ar
    JOIN passage p ON p.passage_id = ar.passage_id
    WHERE p.passage_number BETWEEN ? AND ?
      AND p.clone_id IN ({placeholders})
    GROUP BY p.clone_id
    """

    params = [late_start, late_end] + list(clone_list)
    return pd.read_sql_query(query, conn, params=params)

# %%
conn = sqlite3.connect(DB_PATH)

late_labels = fetch_late_labels(
    conn,
    features["clone_id"].tolist(),
    late_start=24,
    late_end=30
)

conn.close()
late_labels.head()
# Out:
#      clone_id  late_mean_titer  late_mean_aggregation
# 0  CLONE_0001         3.848913               6.305056
# 1  CLONE_0002         1.145400               5.683538
# 2  CLONE_0003         5.253199               2.201984
# 3  CLONE_0004         0.816213               0.954499
# 4  CLONE_0005         3.478779               3.234240

# %%
dataset_3targets = features.merge(
    late_labels,
    on="clone_id",
    how="left"
)
dataset_3targets.head()
# Out:
#      clone_id  titer_mean  titer_std  titer_min  titer_max      vcd_mean  \
# 0  CLONE_0001    4.290966   0.237332   3.898584   4.553147  1.016940e+07
# 1  CLONE_0002    1.134655   0.258193   0.714161   1.444387  1.441390e+07
# 2  CLONE_0003    6.639008   0.255518   6.154533   6.981924  8.031025e+06
# 3  CLONE_0004    1.017127   0.098740   0.919394   1.192629  1.503736e+07
# 4  CLONE_0005    3.844215   0.100473   3.696327   3.970858  1.115742e+07
#
#         vcd_std       vcd_min       vcd_max  viability_mean  ...  titer_cv  \
# 0  1.094181e+06  9.037823e+06  1.218882e+07       94.660676  ...  0.055310
# 1  5.821027e+05  1.342995e+07  1.518339e+07       96.027597  ...  0.227552
# 2  9.000477e+05  6.624924e+06  8.915702e+06       93.638460  ...  0.038487
# 3  6.149093e+05  1.394330e+07  1.602700e+07       95.656109  ...  0.097078
# 4  6.590394e+05  1.039616e+07  1.237306e+07       94.434050  ...  0.026136
#
#      vcd_cv  viability_cv  aggregation_cv  culture_mode_fed-batch  \
# 0  0.107595      0.010232        0.058636                    True
# 1  0.040385      0.019042        0.042814                   False
# 2  0.112071      0.015079        0.325755                    True
# 3  0.040892      0.017374        0.371007                    True
# 4  0.059067      0.016246        0.090028                    True
#
#    culture_mode_perfusion  ddpcr_cn  productivity_drop_pct  late_mean_titer  \
# 0                   False       4.0               0.087531         3.848913
# 1                    True       2.0              -0.097540         1.145400
# 2                   False       4.0               0.230329         5.253199
# 3                   False       3.0               0.184845         0.816213
# 4                   False       4.0               0.070410         3.478779
#
#    late_mean_aggregation
# 0               6.305056
# 1               5.683538
# 2               2.201984
# 3               0.954499
# 4               3.234240
#
# [5 rows x 49 columns]

# %%
dataset_3targets[
    ["productivity_drop_pct", "late_mean_titer", "late_mean_aggregation"]
].isna().mean()
# Out:
# productivity_drop_pct    0.0
# late_mean_titer          0.0
# late_mean_aggregation    0.0
# dtype: float64

# %%
out_dir = Path(OUT_PATH).parent
out_dir.mkdir(parents=True, exist_ok=True)

dataset_3targets.to_csv(OUT_PATH, index=False)
print("Saved:", OUT_PATH)
# Out:
# Saved: ../data/synthetic/processed/cld_features_with_labels_3targets_v2_24_30_5000_optimized.csv

# %% [markdown]
# ### Output
#
# We generated a **multi-target CLD dataset** with:
#
# - Early-stage features (v2)
# - Stability target: `productivity_drop_pct`
# - Productivity target: `late_mean_titer`
# - Quality target: `late_mean_aggregation`
#
# This dataset enables:
# - Multi-target regression (Notebook 03b)
# - Predicted-late decision simulation (Notebook 04b)
