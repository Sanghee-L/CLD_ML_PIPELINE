# %% [markdown]
# ### Goal
#
# In real CLD projects, late-stage outcomes (e.g. productivity, quality, stability)
# are *not available* at early decision time.
#
# However, for **model training and validation**, we need to construct *ground-truth*
# late-stage labels from historical (or simulated) data.
#
# In this notebook, we:
#
# - Load early-stage feature table (v2)
# - Compute late-stage outcomes directly from the raw SQLite DB
# - Attach those late labels to the early feature table
# - Save a **multi-target dataset** for downstream modeling
#
# This dataset will be used by:
# - Notebook 03b (multi-target ML models)
# - Notebook 04b (predicted-late-based clone selection)

# %%
import sqlite3
import pandas as pd
from pathlib import Path

# %%
# Paths
DB_PATH = "../data/synthetic/raw/cld_2000clones_legacy.db"  # or cld.db
FEATURE_PATH = "../data/synthetic/processed/cld_features_with_label_v2_legacy.csv"
OUT_PATH = "../data/synthetic/processed/cld_features_with_labels_3targets_v2_24_30_legacy.csv"

print("DB:", DB_PATH)
print("Feature input:", FEATURE_PATH)
print("Output:", OUT_PATH)
# Out:
# DB: ../data/synthetic/raw/cld_2000clones_legacy.db
# Feature input: ../data/synthetic/processed/cld_features_with_label_v2_legacy.csv
# Output: ../data/synthetic/processed/cld_features_with_labels_3targets_v2_24_30_legacy.csv

# %%
features = pd.read_csv(FEATURE_PATH)
features.head()
# Out:
#      clone_id  titer_mean  titer_std  titer_min  titer_max      vcd_mean  \
# 0  CLONE_0001    3.011514   0.275887   2.614747   3.395051  1.156407e+07
# 1  CLONE_0002    0.970018   0.162046   0.748543   1.181380  1.384544e+07
# 2  CLONE_0003    5.296261   0.366734   4.907030   6.014129  8.502629e+06
# 3  CLONE_0004    0.637620   0.196651   0.408817   0.887779  1.517393e+07
# 4  CLONE_0005    2.523701   0.222069   2.271507   2.943052  1.238733e+07
#
#         vcd_std       vcd_min       vcd_max  viability_mean  ...  \
# 0  8.921083e+05  1.019957e+07  1.277338e+07       95.005059  ...
# 1  7.679650e+05  1.282354e+07  1.546446e+07       96.033319  ...
# 2  9.172969e+05  7.015067e+06  9.416054e+06       94.571483  ...
# 3  6.477633e+05  1.422985e+07  1.598010e+07       97.331194  ...
# 4  1.106135e+06  9.918055e+06  1.321024e+07       95.448363  ...
#
#         qP_mean        qP_p10  titer_cv    vcd_cv  viability_cv  \
# 0  2.604199e-07  2.276863e-07  0.091611  0.077145      0.014006
# 1  7.006043e-08  5.552499e-08  0.167055  0.055467      0.016005
# 2  6.228969e-07  5.321285e-07  0.069244  0.107884      0.019524
# 3  4.202073e-08  2.558291e-08  0.308414  0.042689      0.013737
# 4  2.037325e-07  1.916256e-07  0.087993  0.089296      0.019050
#
#    aggregation_cv  culture_mode_fed-batch  culture_mode_perfusion  ddpcr_cn  \
# 0        0.031174                    True                   False       3.0
# 1        0.103074                   False                    True       2.0
# 2        0.026522                    True                   False       4.0
# 3        0.028835                   False                    True       3.0
# 4        0.092025                    True                   False       4.0
#
#    productivity_drop_pct
# 0               0.433932
# 1               0.277294
# 2               0.366299
# 3               0.384501
# 4               0.529021
#
# [5 rows x 47 columns]

# %%
print("Rows:", features.shape[0])
print("Columns:", features.shape[1])
# Out:
# Rows: 2000
# Columns: 47

# %%
def fetch_late_labels(conn, clone_list, late_start=24, late_end=30):
    """
    Compute late-stage mean titer and aggregation per clone.
    """
    if len(clone_list) == 0:
        return pd.DataFrame(
            columns=["clone_id", "late_mean_titer", "late_mean_aggregation"]
        )

    placeholders = ",".join(["?"] * len(clone_list))

    query = f"""
    SELECT
        p.clone_id,
        AVG(CASE WHEN ar.assay_type = 'titer' THEN ar.value END) AS late_mean_titer,
        AVG(CASE WHEN ar.assay_type = 'aggregation' THEN ar.value END) AS late_mean_aggregation
    FROM assay_result ar
    JOIN passage p ON p.passage_id = ar.passage_id
    WHERE p.passage_number BETWEEN ? AND ?
      AND p.clone_id IN ({placeholders})
    GROUP BY p.clone_id
    """

    params = [late_start, late_end] + list(clone_list)
    return pd.read_sql_query(query, conn, params=params)

# %%
conn = sqlite3.connect(DB_PATH)

late_labels = fetch_late_labels(
    conn,
    features["clone_id"].tolist(),
    late_start=24,
    late_end=30
)

conn.close()
late_labels.head()
# Out:
#      clone_id  late_mean_titer  late_mean_aggregation
# 0  CLONE_0001         1.738644               5.416556
# 1  CLONE_0002         0.710455               3.827088
# 2  CLONE_0003         3.498240               6.653009
# 3  CLONE_0004         0.458249               9.024705
# 4  CLONE_0005         1.246965               2.854237

# %%
dataset_3targets = features.merge(
    late_labels,
    on="clone_id",
    how="left"
)
dataset_3targets.head()
# Out:
#      clone_id  titer_mean  titer_std  titer_min  titer_max      vcd_mean  \
# 0  CLONE_0001    3.011514   0.275887   2.614747   3.395051  1.156407e+07
# 1  CLONE_0002    0.970018   0.162046   0.748543   1.181380  1.384544e+07
# 2  CLONE_0003    5.296261   0.366734   4.907030   6.014129  8.502629e+06
# 3  CLONE_0004    0.637620   0.196651   0.408817   0.887779  1.517393e+07
# 4  CLONE_0005    2.523701   0.222069   2.271507   2.943052  1.238733e+07
#
#         vcd_std       vcd_min       vcd_max  viability_mean  ...  titer_cv  \
# 0  8.921083e+05  1.019957e+07  1.277338e+07       95.005059  ...  0.091611
# 1  7.679650e+05  1.282354e+07  1.546446e+07       96.033319  ...  0.167055
# 2  9.172969e+05  7.015067e+06  9.416054e+06       94.571483  ...  0.069244
# 3  6.477633e+05  1.422985e+07  1.598010e+07       97.331194  ...  0.308414
# 4  1.106135e+06  9.918055e+06  1.321024e+07       95.448363  ...  0.087993
#
#      vcd_cv  viability_cv  aggregation_cv  culture_mode_fed-batch  \
# 0  0.077145      0.014006        0.031174                    True
# 1  0.055467      0.016005        0.103074                   False
# 2  0.107884      0.019524        0.026522                    True
# 3  0.042689      0.013737        0.028835                   False
# 4  0.089296      0.019050        0.092025                    True
#
#    culture_mode_perfusion  ddpcr_cn  productivity_drop_pct  late_mean_titer  \
# 0                   False       3.0               0.433932         1.738644
# 1                    True       2.0               0.277294         0.710455
# 2                   False       4.0               0.366299         3.498240
# 3                    True       3.0               0.384501         0.458249
# 4                   False       4.0               0.529021         1.246965
#
#    late_mean_aggregation
# 0               5.416556
# 1               3.827088
# 2               6.653009
# 3               9.024705
# 4               2.854237
#
# [5 rows x 49 columns]

# %%
dataset_3targets[
    ["productivity_drop_pct", "late_mean_titer", "late_mean_aggregation"]
].isna().mean()
# Out:
# productivity_drop_pct    0.0
# late_mean_titer          0.0
# late_mean_aggregation    0.0
# dtype: float64

# %%
out_dir = Path(OUT_PATH).parent
out_dir.mkdir(parents=True, exist_ok=True)

dataset_3targets.to_csv(OUT_PATH, index=False)
print("Saved:", OUT_PATH)
# Out:
# Saved: ../data/synthetic/processed/cld_features_with_labels_3targets_v2_24_30_legacy.csv

# %% [markdown]
# ### Output
#
# We generated a **multi-target CLD dataset** with:
#
# - Early-stage features (v2)
# - Stability target: `productivity_drop_pct`
# - Productivity target: `late_mean_titer`
# - Quality target: `late_mean_aggregation`
#
# This dataset enables:
# - Multi-target regression (Notebook 03b)
# - Predicted-late decision simulation (Notebook 04b)
